# %% [markdown]
# ## 20200923-181126-network-RMSprop

# %%
import tensorflow as tf
import numpy as np
import sys
sys.path.append('../../')
import utils.data_preprocess as preprocess
from utils.model_metrics import ModelMetric
from utils.mode_figure import ModelFigre
import datetime
from utils.model_callback import step_decay, exp_decay, MyStopTrainCallBack

# %%
# my_devices = tf.config.experimental.list_physical_devices(device_type='CPU')
# tf.config.experimental.set_visible_devices(devices= my_devices, device_type='CPU')
# # To find out which devices your operations and tensors are assigned to
# tf.debugging.set_log_device_placement(True)
import os
os.environ["CUDA_VISIBLE_DEVICES"]="-1"

# %%
modelmetric = ModelMetric()

# %%
from tensorflow.keras.layers import LSTM, Bidirectional, BatchNormalization, GaussianNoise, Flatten, Dense, Input, Activation
from tensorflow.keras import Model
dos_input = Input(shape=(1, 77))
forward_layer_one = LSTM(64, kernel_constraint=tf.keras.constraints.MaxNorm(max_value=4) , recurrent_constraint=tf.keras.constraints.MaxNorm(max_value=4), return_sequences=True)
backward_layer_one = LSTM(64, kernel_constraint=tf.keras.constraints.MaxNorm(max_value=4) , recurrent_constraint=tf.keras.constraints.MaxNorm(max_value=4), return_sequences=True , go_backwards=True)
bi_one = Bidirectional(forward_layer_one, backward_layer=backward_layer_one, name='bi_one')(dos_input)

noise_one = GaussianNoise(0.5)(bi_one)

bn_one = BatchNormalization()(noise_one)

forward_layer_two = LSTM(32, return_sequences=True)
backward_layer_two = LSTM(32, return_sequences=True, go_backwards=True)
bi_two = Bidirectional(forward_layer_two, backward_layer=backward_layer_two, name='bi_two')(bn_one)

bn_two = BatchNormalization()(bi_two)

forward_layer_three = LSTM(16,)
backward_layer_three = LSTM(16, go_backwards=True)
bi_three = Bidirectional(forward_layer_three, backward_layer=backward_layer_three, name='bi_three')(bn_two)

bn_three = BatchNormalization()(bi_three)

flatten_one = Flatten()(bn_three)

dense_four = Dense(16, kernel_constraint=tf.keras.constraints.MaxNorm(max_value=4), name='dense_three')(flatten_one)
noise_two = GaussianNoise(0.5)(dense_four)
avtivation_four = Activation(tf.nn.relu6, name='dense_four_activation')(noise_two)

bn_four = BatchNormalization()(avtivation_four)

dense = Dense(2, name='classification')(bn_four)
output_res = Activation(tf.nn.softmax, name='classifi')(dense)

model = Model(inputs=dos_input, outputs=output_res)

# algorithm = tf.keras.optimizers.RMSprop(learning_rate=0.001, rho=0.9, clipvalue=0.3, momentum=0.9, epsilon=1e-07, decay= 1e-06, centered=False, name='RMSprop')
algorithm = tf.keras.optimizers.SGD(learning_rate=0.05, momentum=0.99, clipvalue=0.2, nesterov=True, name='SGD')

model.compile(optimizer=algorithm, loss='binary_crossentropy', metrics=modelmetric.metric('binary_crossentropy')) # categorical_crossentropycategorical_crossentropy

# %%
from tensorflow.keras import callbacks
dir_name = datetime.datetime.now().strftime("CPU-Best-%Y%m%d-%H%M%S-SGD")

logdir = os.path.join("../../tensorboard", dir_name)
tensorboard_callback = callbacks.TensorBoard(logdir, histogram_freq=1)
lrate = callbacks.LearningRateScheduler(step_decay)
csv_log = tf.keras.callbacks.CSVLogger('../../model_record/CPU/'+dir_name+"/log", separator=',', append=False)
if not os.path.isdir('../../model_record/CPU/'+dir_name):
    os.mkdir('../../model_record/CPU/'+dir_name)
    os.mkdir('../../model_record/CPU/'+dir_name+'/model')
# stop_train = MyStopTrainCallBack()
# callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
pre = preprocess.preprocess("D:/DataSet/CICIDS2017/CSV/Wednesday-workingHours.pcap_ISCX.csv", labelColumnName='Label', depth=2)
X_train, X_test, y_train, y_test = pre.preprocessing()
X_train = tf.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = tf.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
import numpy as np
model_ = model.fit(X_train, y_train, epochs=100, batch_size=512, validation_split=0.3, callbacks=[tensorboard_callback, csv_log, lrate], verbose=1) # lrate
# Out:
# l_precision: 0.9856 - val_recall: 0.9856 - val_auc: 0.9990 - val_binary_accuracy: 0.9856 - val_binary_crossentropy: 0.0396
# Epoch 63/100
# 662/662 [==============================] - 13s 19ms/step - loss: 0.0424 - tp: 333493.0000 - fp: 5295.0000 - tn: 333493.0000 - fn: 5295.0000 - acc: 0.0021 - precision: 0.9844 - recall: 0.9844 - auc: 0.9988 - binary_accuracy: 0.9844 - binary_crossentropy: 0.0424 - val_loss: 0.0397 - val_tp: 143083.0000 - val_fp: 2113.0000 - val_tn: 143083.0000 - val_fn: 2113.0000 - val_acc: 0.0013 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9990 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0397
# Epoch 64/100
# 662/662 [==============================] - 13s 19ms/step - loss: 0.0423 - tp: 333538.0000 - fp: 5250.0000 - tn: 333538.0000 - fn: 5250.0000 - acc: 0.0027 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0423 - val_loss: 0.0396 - val_tp: 143097.0000 - val_fp: 2099.0000 - val_tn: 143097.0000 - val_fn: 2099.0000 - val_acc: 0.0015 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9990 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0396
# Epoch 65/100
# 662/662 [==============================] - 13s 19ms/step - loss: 0.0422 - tp: 333569.0000 - fp: 5219.0000 - tn: 333569.0000 - fn: 5219.0000 - acc: 0.0027 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - binary_accuracy: 0.9846 - binary_crossentropy: 0.0422 - val_loss: 0.0396 - val_tp: 143099.0000 - val_fp: 2097.0000 - val_tn: 143099.0000 - val_fn: 2097.0000 - val_acc: 0.0013 - val_precision: 0.9856 - val_recall: 0.9856 - val_auc: 0.9990 - val_binary_accuracy: 0.9856 - val_binary_crossentropy: 0.0396
# Epoch 66/100
# 662/662 [==============================] - 13s 19ms/step - loss: 0.0421 - tp: 333570.0000 - fp: 5218.0000 - tn: 333570.0000 - fn: 5218.0000 - acc: 0.0020 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - binary_accuracy: 0.9846 - binary_crossentropy: 0.0421 - val_loss: 0.0396 - val_tp: 143094.0000 - val_fp: 2102.0000 - val_tn: 143094.0000 - val_fn: 2102.0000 - val_acc: 5.6475e-04 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9990 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0396
# Epoch 67/100
# 662/662 [==============================] - 16s 24ms/step - loss: 0.0421 - tp: 333565.0000 - fp: 5223.0000 - tn: 333565.0000 - fn: 5223.0000 - acc: 0.0017 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - binary_accuracy: 0.9846 - binary_crossentropy: 0.0421 - val_loss: 0.0396 - val_tp: 143087.0000 - val_fp: 2109.0000 - val_tn: 143087.0000 - val_fn: 2109.0000 - val_acc: 7.6793e-04 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9990 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0396
# Epoch 68/100
# 662/662 [==============================] - 14s 21ms/step - loss: 0.0423 - tp: 333539.0000 - fp: 5249.0000 - tn: 333539.0000 - fn: 5249.0000 - acc: 0.0016 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0423 - val_loss: 0.0396 - val_tp: 143093.0000 - val_fp: 2103.0000 - val_tn: 143093.0000 - val_fn: 2103.0000 - val_acc: 4.2357e-04 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9989 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0396
# Epoch 69/100
# 662/662 [==============================] - 13s 19ms/step - loss: 0.0421 - tp: 333556.0000 - fp: 5232.0000 - tn: 333556.0000 - fn: 5232.0000 - acc: 0.0018 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - binary_accuracy: 0.9846 - binary_crossentropy: 0.0421 - val_loss: 0.0396 - val_tp: 143094.0000 - val_fp: 2102.0000 - val_tn: 143094.0000 - val_fn: 2102.0000 - val_acc: 5.3376e-04 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9990 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0396
# Epoch 70/100
# 662/662 [==============================] - 13s 20ms/step - loss: 0.0422 - tp: 333560.0000 - fp: 5228.0000 - tn: 333560.0000 - fn: 5228.0000 - acc: 0.0019 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - binary_accuracy: 0.9846 - binary_crossentropy: 0.0422 - val_loss: 0.0396 - val_tp: 143094.0000 - val_fp: 2102.0000 - val_tn: 143094.0000 - val_fn: 2102.0000 - val_acc: 6.7495e-04 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9990 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0396
# Epoch 71/100
# 662/662 [==============================] - 13s 19ms/step - loss: 0.0421 - tp: 333544.0000 - fp: 5244.0000 - tn: 333544.0000 - fn: 5244.0000 - acc: 0.0017 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0421 - val_loss: 0.0396 - val_tp: 143099.0000 - val_fp: 2097.0000 - val_tn: 143099.0000 - val_fn: 2097.0000 - val_acc: 7.4382e-04 - val_precision: 0.9856 - val_recall: 0.9856 - val_auc: 0.9990 - val_binary_accuracy: 0.9856 - val_binary_crossentropy: 0.0396
# Epoch 72/100
# 662/662 [==============================] - 14s 22ms/step - loss: 0.0423 - tp: 333548.0000 - fp: 5240.0000 - tn: 333548.0000 - fn: 5240.0000 - acc: 0.0018 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0423 - val_loss: 0.0395 - val_tp: 143098.0000 - val_fp: 2098.0000 - val_tn: 143098.0000 - val_fn: 2098.0000 - val_acc: 6.3018e-04 - val_precision: 0.9856 - val_recall: 0.9856 - val_auc: 0.9989 - val_binary_accuracy: 0.9856 - val_binary_crossentropy: 0.0395
# Epoch 73/100
# 662/662 [==============================] - 12s 19ms/step - loss: 0.0419 - tp: 333606.0000 - fp: 5182.0000 - tn: 333606.0000 - fn: 5182.0000 - acc: 0.0020 - precision: 0.9847 - recall: 0.9847 - auc: 0.9988 - binary_accuracy: 0.9847 - binary_crossentropy: 0.0419 - val_loss: 0.0396 - val_tp: 143095.0000 - val_fp: 2101.0000 - val_tn: 143095.0000 - val_fn: 2101.0000 - val_acc: 7.2316e-04 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9990 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0396
# Epoch 74/100
# 662/662 [==============================] - 13s 20ms/step - loss: 0.0420 - tp: 333572.0000 - fp: 5216.0000 - tn: 333572.0000 - fn: 5216.0000 - acc: 0.0022 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - binary_accuracy: 0.9846 - binary_crossentropy: 0.0420 - val_loss: 0.0396 - val_tp: 143095.0000 - val_fp: 2101.0000 - val_tn: 143095.0000 - val_fn: 2101.0000 - val_acc: 0.0012 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9990 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0396
# Epoch 75/100
# 662/662 [==============================] - 15s 23ms/step - loss: 0.0423 - tp: 333507.0000 - fp: 5281.0000 - tn: 333507.0000 - fn: 5281.0000 - acc: 0.0022 - precision: 0.9844 - recall: 0.9844 - auc: 0.9988 - binary_accuracy: 0.9844 - binary_crossentropy: 0.0423 - val_loss: 0.0396 - val_tp: 143096.0000 - val_fp: 2100.0000 - val_tn: 143096.0000 - val_fn: 2100.0000 - val_acc: 0.0011 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9989 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0396
# Epoch 76/100
# 662/662 [==============================] - 15s 22ms/step - loss: 0.0423 - tp: 333524.0000 - fp: 5264.0000 - tn: 333524.0000 - fn: 5264.0000 - acc: 0.0024 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0423 - val_loss: 0.0397 - val_tp: 143088.0000 - val_fp: 2108.0000 - val_tn: 143088.0000 - val_fn: 2108.0000 - val_acc: 0.0011 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9989 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0397
# Epoch 77/100
# 662/662 [==============================] - 12s 18ms/step - loss: 0.0420 - tp: 333546.0000 - fp: 5242.0000 - tn: 333546.0000 - fn: 5242.0000 - acc: 0.0025 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0420 - val_loss: 0.0397 - val_tp: 143093.0000 - val_fp: 2103.0000 - val_tn: 143093.0000 - val_fn: 2103.0000 - val_acc: 0.0012 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9990 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0397
# Epoch 78/100
# 662/662 [==============================] - 14s 21ms/step - loss: 0.0422 - tp: 333569.0000 - fp: 5219.0000 - tn: 333569.0000 - fn: 5219.0000 - acc: 0.0026 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - binary_accuracy: 0.9846 - binary_crossentropy: 0.0422 - val_loss: 0.0395 - val_tp: 143098.0000 - val_fp: 2098.0000 - val_tn: 143098.0000 - val_fn: 2098.0000 - val_acc: 0.0011 - val_precision: 0.9856 - val_recall: 0.9856 - val_auc: 0.9990 - val_binary_accuracy: 0.9856 - val_binary_crossentropy: 0.0395
# Epoch 79/100
# 662/662 [==============================] - 14s 21ms/step - loss: 0.0421 - tp: 333550.0000 - fp: 5238.0000 - tn: 333550.0000 - fn: 5238.0000 - acc: 0.0025 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0421 - val_loss: 0.0396 - val_tp: 143094.0000 - val_fp: 2102.0000 - val_tn: 143094.0000 - val_fn: 2102.0000 - val_acc: 0.0012 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9990 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0396
# Epoch 80/100
# 662/662 [==============================] - 13s 20ms/step - loss: 0.0422 - tp: 333546.0000 - fp: 5242.0000 - tn: 333546.0000 - fn: 5242.0000 - acc: 0.0025 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0422 - val_loss: 0.0396 - val_tp: 143095.0000 - val_fp: 2101.0000 - val_tn: 143095.0000 - val_fn: 2101.0000 - val_acc: 0.0011 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9990 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0396
# Epoch 81/100
# 662/662 [==============================] - 15s 23ms/step - loss: 0.0423 - tp: 333549.0000 - fp: 5239.0000 - tn: 333549.0000 - fn: 5239.0000 - acc: 0.0027 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0423 - val_loss: 0.0396 - val_tp: 143095.0000 - val_fp: 2101.0000 - val_tn: 143095.0000 - val_fn: 2101.0000 - val_acc: 0.0013 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9989 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0396
# Epoch 82/100
# 662/662 [==============================] - 13s 19ms/step - loss: 0.0420 - tp: 333555.0000 - fp: 5233.0000 - tn: 333555.0000 - fn: 5233.0000 - acc: 0.0025 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - binary_accuracy: 0.9846 - binary_crossentropy: 0.0420 - val_loss: 0.0396 - val_tp: 143095.0000 - val_fp: 2101.0000 - val_tn: 143095.0000 - val_fn: 2101.0000 - val_acc: 0.0011 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9990 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0396
# Epoch 83/100
# 662/662 [==============================] - 12s 19ms/step - loss: 0.0421 - tp: 333552.0000 - fp: 5236.0000 - tn: 333552.0000 - fn: 5236.0000 - acc: 0.0025 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0421 - val_loss: 0.0396 - val_tp: 143095.0000 - val_fp: 2101.0000 - val_tn: 143095.0000 - val_fn: 2101.0000 - val_acc: 0.0010 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9990 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0396
# Epoch 84/100
# 662/662 [==============================] - 15s 22ms/step - loss: 0.0423 - tp: 333550.0000 - fp: 5238.0000 - tn: 333550.0000 - fn: 5238.0000 - acc: 0.0026 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0423 - val_loss: 0.0396 - val_tp: 143098.0000 - val_fp: 2098.0000 - val_tn: 143098.0000 - val_fn: 2098.0000 - val_acc: 8.4024e-04 - val_precision: 0.9856 - val_recall: 0.9856 - val_auc: 0.9990 - val_binary_accuracy: 0.9856 - val_binary_crossentropy: 0.0396
# Epoch 85/100
# 662/662 [==============================] - 20s 31ms/step - loss: 0.0421 - tp: 333575.0000 - fp: 5213.0000 - tn: 333575.0000 - fn: 5213.0000 - acc: 0.0025 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - binary_accuracy: 0.9846 - binary_crossentropy: 0.0421 - val_loss: 0.0396 - val_tp: 143096.0000 - val_fp: 2100.0000 - val_tn: 143096.0000 - val_fn: 2100.0000 - val_acc: 0.0011 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9990 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0396
# Epoch 86/100
# 662/662 [==============================] - 12s 19ms/step - loss: 0.0423 - tp: 333552.0000 - fp: 5236.0000 - tn: 333552.0000 - fn: 5236.0000 - acc: 0.0026 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0423 - val_loss: 0.0396 - val_tp: 143098.0000 - val_fp: 2098.0000 - val_tn: 143098.0000 - val_fn: 2098.0000 - val_acc: 0.0012 - val_precision: 0.9856 - val_recall: 0.9856 - val_auc: 0.9989 - val_binary_accuracy: 0.9856 - val_binary_crossentropy: 0.0396
# Epoch 87/100
# 662/662 [==============================] - 15s 22ms/step - loss: 0.0421 - tp: 333568.0000 - fp: 5220.0000 - tn: 333568.0000 - fn: 5220.0000 - acc: 0.0026 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - binary_accuracy: 0.9846 - binary_crossentropy: 0.0421 - val_loss: 0.0396 - val_tp: 143098.0000 - val_fp: 2098.0000 - val_tn: 143098.0000 - val_fn: 2098.0000 - val_acc: 0.0013 - val_precision: 0.9856 - val_recall: 0.9856 - val_auc: 0.9989 - val_binary_accuracy: 0.9856 - val_binary_crossentropy: 0.0396
# Epoch 88/100
# 662/662 [==============================] - 16s 24ms/step - loss: 0.0422 - tp: 333544.0000 - fp: 5244.0000 - tn: 333544.0000 - fn: 5244.0000 - acc: 0.0026 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0422 - val_loss: 0.0395 - val_tp: 143099.0000 - val_fp: 2097.0000 - val_tn: 143099.0000 - val_fn: 2097.0000 - val_acc: 9.9521e-04 - val_precision: 0.9856 - val_recall: 0.9856 - val_auc: 0.9990 - val_binary_accuracy: 0.9856 - val_binary_crossentropy: 0.0395
# Epoch 89/100
# 662/662 [==============================] - 13s 20ms/step - loss: 0.0422 - tp: 333516.0000 - fp: 5272.0000 - tn: 333516.0000 - fn: 5272.0000 - acc: 0.0025 - precision: 0.9844 - recall: 0.9844 - auc: 0.9988 - binary_accuracy: 0.9844 - binary_crossentropy: 0.0422 - val_loss: 0.0396 - val_tp: 143096.0000 - val_fp: 2100.0000 - val_tn: 143096.0000 - val_fn: 2100.0000 - val_acc: 0.0012 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9989 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0396
# Epoch 90/100
# 662/662 [==============================] - 16s 25ms/step - loss: 0.0421 - tp: 333555.0000 - fp: 5233.0000 - tn: 333555.0000 - fn: 5233.0000 - acc: 0.0026 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - binary_accuracy: 0.9846 - binary_crossentropy: 0.0421 - val_loss: 0.0395 - val_tp: 143100.0000 - val_fp: 2096.0000 - val_tn: 143100.0000 - val_fn: 2096.0000 - val_acc: 0.0011 - val_precision: 0.9856 - val_recall: 0.9856 - val_auc: 0.9990 - val_binary_accuracy: 0.9856 - val_binary_crossentropy: 0.0395
# Epoch 91/100
# 662/662 [==============================] - 12s 19ms/step - loss: 0.0421 - tp: 333545.0000 - fp: 5243.0000 - tn: 333545.0000 - fn: 5243.0000 - acc: 0.0027 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0421 - val_loss: 0.0396 - val_tp: 143098.0000 - val_fp: 2098.0000 - val_tn: 143098.0000 - val_fn: 2098.0000 - val_acc: 0.0012 - val_precision: 0.9856 - val_recall: 0.9856 - val_auc: 0.9990 - val_binary_accuracy: 0.9856 - val_binary_crossentropy: 0.0396
# Epoch 92/100
# 662/662 [==============================] - 14s 21ms/step - loss: 0.0420 - tp: 333564.0000 - fp: 5224.0000 - tn: 333564.0000 - fn: 5224.0000 - acc: 0.0026 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - binary_accuracy: 0.9846 - binary_crossentropy: 0.0420 - val_loss: 0.0396 - val_tp: 143096.0000 - val_fp: 2100.0000 - val_tn: 143096.0000 - val_fn: 2100.0000 - val_acc: 0.0012 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9990 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0396
# Epoch 93/100
# 662/662 [==============================] - 13s 20ms/step - loss: 0.0422 - tp: 333525.0000 - fp: 5263.0000 - tn: 333525.0000 - fn: 5263.0000 - acc: 0.0028 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0422 - val_loss: 0.0396 - val_tp: 143089.0000 - val_fp: 2107.0000 - val_tn: 143089.0000 - val_fn: 2107.0000 - val_acc: 0.0011 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9989 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0396
# Epoch 94/100
# 662/662 [==============================] - 13s 19ms/step - loss: 0.0421 - tp: 333533.0000 - fp: 5255.0000 - tn: 333533.0000 - fn: 5255.0000 - acc: 0.0028 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0421 - val_loss: 0.0396 - val_tp: 143095.0000 - val_fp: 2101.0000 - val_tn: 143095.0000 - val_fn: 2101.0000 - val_acc: 0.0011 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9990 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0396
# Epoch 95/100
# 662/662 [==============================] - 13s 20ms/step - loss: 0.0422 - tp: 333536.0000 - fp: 5252.0000 - tn: 333536.0000 - fn: 5252.0000 - acc: 0.0027 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0422 - val_loss: 0.0396 - val_tp: 143096.0000 - val_fp: 2100.0000 - val_tn: 143096.0000 - val_fn: 2100.0000 - val_acc: 0.0011 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9990 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0396
# Epoch 96/100
# 662/662 [==============================] - 13s 19ms/step - loss: 0.0418 - tp: 333585.0000 - fp: 5203.0000 - tn: 333585.0000 - fn: 5203.0000 - acc: 0.0026 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - binary_accuracy: 0.9846 - binary_crossentropy: 0.0418 - val_loss: 0.0395 - val_tp: 143100.0000 - val_fp: 2096.0000 - val_tn: 143100.0000 - val_fn: 2096.0000 - val_acc: 0.0013 - val_precision: 0.9856 - val_recall: 0.9856 - val_auc: 0.9990 - val_binary_accuracy: 0.9856 - val_binary_crossentropy: 0.0395
# Epoch 97/100
# 662/662 [==============================] - 12s 19ms/step - loss: 0.0422 - tp: 333515.0000 - fp: 5273.0000 - tn: 333515.0000 - fn: 5273.0000 - acc: 0.0028 - precision: 0.9844 - recall: 0.9844 - auc: 0.9988 - binary_accuracy: 0.9844 - binary_crossentropy: 0.0422 - val_loss: 0.0395 - val_tp: 143097.0000 - val_fp: 2099.0000 - val_tn: 143097.0000 - val_fn: 2099.0000 - val_acc: 0.0012 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9990 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0395
# Epoch 98/100
# 662/662 [==============================] - 12s 19ms/step - loss: 0.0420 - tp: 333552.0000 - fp: 5236.0000 - tn: 333552.0000 - fn: 5236.0000 - acc: 0.0026 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0420 - val_loss: 0.0396 - val_tp: 143099.0000 - val_fp: 2097.0000 - val_tn: 143099.0000 - val_fn: 2097.0000 - val_acc: 0.0011 - val_precision: 0.9856 - val_recall: 0.9856 - val_auc: 0.9990 - val_binary_accuracy: 0.9856 - val_binary_crossentropy: 0.0396
# Epoch 99/100
# 662/662 [==============================] - 15s 23ms/step - loss: 0.0420 - tp: 333551.0000 - fp: 5237.0000 - tn: 333551.0000 - fn: 5237.0000 - acc: 0.0026 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0420 - val_loss: 0.0396 - val_tp: 143097.0000 - val_fp: 2099.0000 - val_tn: 143097.0000 - val_fn: 2099.0000 - val_acc: 0.0011 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9989 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0396
# Epoch 100/100
# 662/662 [==============================] - 12s 18ms/step - loss: 0.0423 - tp: 333503.0000 - fp: 5285.0000 - tn: 333503.0000 - fn: 5285.0000 - acc: 0.0028 - precision: 0.9844 - recall: 0.9844 - auc: 0.9988 - binary_accuracy: 0.9844 - binary_crossentropy: 0.0423 - val_loss: 0.0396 - val_tp: 143098.0000 - val_fp: 2098.0000 - val_tn: 143098.0000 - val_fn: 2098.0000 - val_acc: 0.0013 - val_precision: 0.9856 - val_recall: 0.9856 - val_auc: 0.9990 - val_binary_accuracy: 0.9856 - val_binary_crossentropy: 0.0396

# %%
results  = model.evaluate(X_test, y_test, verbose=1)
modelmetric.getTrainMetricValue(model, results)
# Out:
# 6482/6482 [==============================] - 48s 7ms/step - loss: 0.0413 - tp: 204314.0000 - fp: 3108.0000 - tn: 204314.0000 - fn: 3108.0000 - acc: 0.0013 - precision: 0.9850 - recall: 0.9850 - auc: 0.9988 - binary_accuracy: 0.9850 - binary_crossentropy: 0.0413
# loss :  0.04132784530520439
# tp :  204314.0
# fp :  3108.0
# tn :  204314.0
# fn :  3108.0
# acc :  0.0012655359460040927
# precision :  0.9850160479545593
# recall :  0.9850160479545593
# auc :  0.9988121390342712
# binary_accuracy :  0.9850160479545593
# binary_crossentropy :  0.04132784530520439

# %%
y_pred = model.predict(X_test)
y_class = np.argmax(y_pred, axis=1)
y_label = np.argmax(y_test, axis=1)
modelmetric.confusion_matrix(y_label, y_class)
modelmetric.eva_metric(y_label, y_class)
# Out:
# TrueNegatives result:  129075.0
# TruePositives result:  75239.0
# FalseNegatives result:  174.0
# FalsePositives result:  2934.0
# Recall result:  0.9976927
# Precision result:  0.96246785

# %%
mf = ModelFigre("../../model_record/CPU/", dir_name, model_)
mf.loss_graph()
mf.recall_graph()
mf.precision_graph()
mf.cross_entropy_graph()
# fig.save_model(net,dir_name)
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
mf.lr_graph()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
model.save('../../model_record/CPU/'+dir_name+'/model/model.h5')
