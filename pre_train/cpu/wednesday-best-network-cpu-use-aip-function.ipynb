# %% [markdown]
# ## 20200923-181126-network-RMSprop

# %%
import tensorflow as tf
import numpy as np
import sys
sys.path.append('../../')
import utils.data_preprocess as preprocess
from utils.model_metrics import ModelMetric
from utils.mode_figure import ModelFigre
import datetime
from utils.model_callback import step_decay, exp_decay, MyStopTrainCallBack

# %%
modelmetric = ModelMetric()

# %%
from tensorflow.keras.layers import LSTM, Bidirectional, BatchNormalization, GaussianNoise, Flatten, Dense, Input, Activation
from tensorflow.keras import Model
dos_input = Input(shape=(1, 77))
forward_layer_one = LSTM(64, kernel_constraint=tf.keras.constraints.MaxNorm(max_value=4) , recurrent_constraint=tf.keras.constraints.MaxNorm(max_value=4), return_sequences=True)
backward_layer_one = LSTM(64, kernel_constraint=tf.keras.constraints.MaxNorm(max_value=4) , recurrent_constraint=tf.keras.constraints.MaxNorm(max_value=4), return_sequences=True , go_backwards=True)
bi_one = Bidirectional(forward_layer_one, backward_layer=backward_layer_one, name='bi_one')(dos_input)

noise_one = GaussianNoise(0.5)(bi_one)

bn_one = BatchNormalization()(noise_one)

forward_layer_two = LSTM(32, return_sequences=True)
backward_layer_two = LSTM(32, return_sequences=True, go_backwards=True)
bi_two = Bidirectional(forward_layer_two, backward_layer=backward_layer_two, name='bi_two')(bn_one)

bn_two = BatchNormalization()(bi_two)

forward_layer_three = LSTM(16,)
backward_layer_three = LSTM(16, go_backwards=True)
bi_three = Bidirectional(forward_layer_three, backward_layer=backward_layer_three, name='bi_three')(bn_two)

bn_three = BatchNormalization()(bi_three)

flatten_one = Flatten()(bn_three)

dense_four = Dense(16, kernel_constraint=tf.keras.constraints.MaxNorm(max_value=4), name='dense_three')(flatten_one)
noise_two = GaussianNoise(0.5)(dense_four)
avtivation_four = Activation(tf.nn.relu6, name='dense_four_activation')(noise_two)

bn_four = BatchNormalization()(avtivation_four)

dense = Dense(2, name='classification')(bn_four)
output_res = Activation(tf.nn.softmax, name='classifi')(dense)

model = Model(inputs=dos_input, outputs=output_res)

# algorithm = tf.keras.optimizers.RMSprop(learning_rate=0.001, rho=0.9, clipvalue=0.3, momentum=0.9, epsilon=1e-07, decay= 1e-06, centered=False, name='RMSprop')
algorithm = tf.keras.optimizers.SGD(learning_rate=0.05, momentum=0.99, clipvalue=0.2, nesterov=True, name='SGD')

model.compile(optimizer=algorithm, loss='binary_crossentropy', metrics=modelmetric.metric('binary_crossentropy')) # categorical_crossentropycategorical_crossentropy

# %%
from tensorflow.keras import callbacks
dir_name = datetime.datetime.now().strftime("CPU-Best-%Y%m%d-%H%M%S-SGD")

logdir = os.path.join("../../tensorboard", dir_name)
tensorboard_callback = callbacks.TensorBoard(logdir, histogram_freq=1)
lrate = callbacks.LearningRateScheduler(step_decay)
csv_log = tf.keras.callbacks.CSVLogger('../../model_record/CPU/'+dir_name+"/log", separator=',', append=False)
if not os.path.isdir('../../model_record/CPU/'+dir_name):
    os.mkdir('../../model_record/CPU/'+dir_name)
    os.mkdir('../../model_record/CPU/'+dir_name+'/model')
# stop_train = MyStopTrainCallBack()
# callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
pre = preprocess.preprocess("D:/DataSet/CICIDS2017/CSV/Wednesday-workingHours.pcap_ISCX.csv", labelColumnName='Label', depth=2)
X_train, X_test, y_train, y_test = pre.preprocessing()
X_train = tf.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = tf.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
import numpy as np
model_ = model.fit(X_train, y_train, epochs=100, batch_size=512, validation_split=0.3, callbacks=[tensorboard_callback, csv_log, lrate], verbose=1) # lrate
# Out:
# val_fn: 2233.0000 - val_acc: 0.0090 - val_precision: 0.9846 - val_recall: 0.9846 - val_auc: 0.9989 - val_binary_accuracy: 0.9846 - val_binary_crossentropy: 0.0416
# Epoch 63/100
# 662/662 [==============================] - 22s 34ms/step - loss: 0.0410 - tp: 333688.0000 - fp: 5100.0000 - tn: 333688.0000 - fn: 5100.0000 - acc: 0.0090 - precision: 0.9849 - recall: 0.9849 - auc: 0.9989 - binary_accuracy: 0.9849 - binary_crossentropy: 0.0410 - val_loss: 0.0415 - val_tp: 142965.0000 - val_fp: 2231.0000 - val_tn: 142965.0000 - val_fn: 2231.0000 - val_acc: 0.0100 - val_precision: 0.9846 - val_recall: 0.9846 - val_auc: 0.9988 - val_binary_accuracy: 0.9846 - val_binary_crossentropy: 0.0415
# Epoch 64/100
# 662/662 [==============================] - 19s 29ms/step - loss: 0.0410 - tp: 333705.0000 - fp: 5083.0000 - tn: 333705.0000 - fn: 5083.0000 - acc: 0.0091 - precision: 0.9850 - recall: 0.9850 - auc: 0.9989 - binary_accuracy: 0.9850 - binary_crossentropy: 0.0410 - val_loss: 0.0414 - val_tp: 142975.0000 - val_fp: 2221.0000 - val_tn: 142975.0000 - val_fn: 2221.0000 - val_acc: 0.0134 - val_precision: 0.9847 - val_recall: 0.9847 - val_auc: 0.9989 - val_binary_accuracy: 0.9847 - val_binary_crossentropy: 0.0414
# Epoch 65/100
# 662/662 [==============================] - 18s 27ms/step - loss: 0.0409 - tp: 333734.0000 - fp: 5054.0000 - tn: 333734.0000 - fn: 5054.0000 - acc: 0.0096 - precision: 0.9851 - recall: 0.9851 - auc: 0.9988 - binary_accuracy: 0.9851 - binary_crossentropy: 0.0409 - val_loss: 0.0414 - val_tp: 142963.0000 - val_fp: 2233.0000 - val_tn: 142963.0000 - val_fn: 2233.0000 - val_acc: 0.0100 - val_precision: 0.9846 - val_recall: 0.9846 - val_auc: 0.9989 - val_binary_accuracy: 0.9846 - val_binary_crossentropy: 0.0414
# Epoch 66/100
# 662/662 [==============================] - 17s 26ms/step - loss: 0.0411 - tp: 333683.0000 - fp: 5105.0000 - tn: 333683.0000 - fn: 5105.0000 - acc: 0.0100 - precision: 0.9849 - recall: 0.9849 - auc: 0.9989 - binary_accuracy: 0.9849 - binary_crossentropy: 0.0411 - val_loss: 0.0416 - val_tp: 142951.0000 - val_fp: 2245.0000 - val_tn: 142951.0000 - val_fn: 2245.0000 - val_acc: 0.0135 - val_precision: 0.9845 - val_recall: 0.9845 - val_auc: 0.9989 - val_binary_accuracy: 0.9845 - val_binary_crossentropy: 0.0416
# Epoch 67/100
# 662/662 [==============================] - 18s 27ms/step - loss: 0.0412 - tp: 333687.0000 - fp: 5101.0000 - tn: 333687.0000 - fn: 5101.0000 - acc: 0.0114 - precision: 0.9849 - recall: 0.9849 - auc: 0.9988 - binary_accuracy: 0.9849 - binary_crossentropy: 0.0412 - val_loss: 0.0416 - val_tp: 142961.0000 - val_fp: 2235.0000 - val_tn: 142961.0000 - val_fn: 2235.0000 - val_acc: 0.0159 - val_precision: 0.9846 - val_recall: 0.9846 - val_auc: 0.9989 - val_binary_accuracy: 0.9846 - val_binary_crossentropy: 0.0416
# Epoch 68/100
# 662/662 [==============================] - 17s 26ms/step - loss: 0.0409 - tp: 333711.0000 - fp: 5077.0000 - tn: 333711.0000 - fn: 5077.0000 - acc: 0.0111 - precision: 0.9850 - recall: 0.9850 - auc: 0.9989 - binary_accuracy: 0.9850 - binary_crossentropy: 0.0409 - val_loss: 0.0414 - val_tp: 142969.0000 - val_fp: 2227.0000 - val_tn: 142969.0000 - val_fn: 2227.0000 - val_acc: 0.0132 - val_precision: 0.9847 - val_recall: 0.9847 - val_auc: 0.9989 - val_binary_accuracy: 0.9847 - val_binary_crossentropy: 0.0414
# Epoch 69/100
# 662/662 [==============================] - 18s 27ms/step - loss: 0.0410 - tp: 333686.0000 - fp: 5102.0000 - tn: 333686.0000 - fn: 5102.0000 - acc: 0.0109 - precision: 0.9849 - recall: 0.9849 - auc: 0.9989 - binary_accuracy: 0.9849 - binary_crossentropy: 0.0410 - val_loss: 0.0417 - val_tp: 142955.0000 - val_fp: 2241.0000 - val_tn: 142955.0000 - val_fn: 2241.0000 - val_acc: 0.0145 - val_precision: 0.9846 - val_recall: 0.9846 - val_auc: 0.9988 - val_binary_accuracy: 0.9846 - val_binary_crossentropy: 0.0417
# Epoch 70/100
# 662/662 [==============================] - 18s 27ms/step - loss: 0.0407 - tp: 333737.0000 - fp: 5051.0000 - tn: 333737.0000 - fn: 5051.0000 - acc: 0.0110 - precision: 0.9851 - recall: 0.9851 - auc: 0.9989 - binary_accuracy: 0.9851 - binary_crossentropy: 0.0407 - val_loss: 0.0414 - val_tp: 142969.0000 - val_fp: 2227.0000 - val_tn: 142969.0000 - val_fn: 2227.0000 - val_acc: 0.0153 - val_precision: 0.9847 - val_recall: 0.9847 - val_auc: 0.9989 - val_binary_accuracy: 0.9847 - val_binary_crossentropy: 0.0414
# Epoch 71/100
# 662/662 [==============================] - 21s 32ms/step - loss: 0.0407 - tp: 333749.0000 - fp: 5039.0000 - tn: 333749.0000 - fn: 5039.0000 - acc: 0.0120 - precision: 0.9851 - recall: 0.9851 - auc: 0.9989 - binary_accuracy: 0.9851 - binary_crossentropy: 0.0407 - val_loss: 0.0412 - val_tp: 142981.0000 - val_fp: 2215.0000 - val_tn: 142981.0000 - val_fn: 2215.0000 - val_acc: 0.0154 - val_precision: 0.9847 - val_recall: 0.9847 - val_auc: 0.9989 - val_binary_accuracy: 0.9847 - val_binary_crossentropy: 0.0412
# Epoch 72/100
# 662/662 [==============================] - 21s 31ms/step - loss: 0.0408 - tp: 333730.0000 - fp: 5058.0000 - tn: 333730.0000 - fn: 5058.0000 - acc: 0.0122 - precision: 0.9851 - recall: 0.9851 - auc: 0.9989 - binary_accuracy: 0.9851 - binary_crossentropy: 0.0408 - val_loss: 0.0414 - val_tp: 142968.0000 - val_fp: 2228.0000 - val_tn: 142968.0000 - val_fn: 2228.0000 - val_acc: 0.0173 - val_precision: 0.9847 - val_recall: 0.9847 - val_auc: 0.9989 - val_binary_accuracy: 0.9847 - val_binary_crossentropy: 0.0414
# Epoch 73/100
# 662/662 [==============================] - 20s 30ms/step - loss: 0.0409 - tp: 333725.0000 - fp: 5063.0000 - tn: 333725.0000 - fn: 5063.0000 - acc: 0.0111 - precision: 0.9851 - recall: 0.9851 - auc: 0.9989 - binary_accuracy: 0.9851 - binary_crossentropy: 0.0409 - val_loss: 0.0414 - val_tp: 142974.0000 - val_fp: 2222.0000 - val_tn: 142974.0000 - val_fn: 2222.0000 - val_acc: 0.0167 - val_precision: 0.9847 - val_recall: 0.9847 - val_auc: 0.9989 - val_binary_accuracy: 0.9847 - val_binary_crossentropy: 0.0414
# Epoch 74/100
# 662/662 [==============================] - 19s 29ms/step - loss: 0.0411 - tp: 333686.0000 - fp: 5102.0000 - tn: 333686.0000 - fn: 5102.0000 - acc: 0.0114 - precision: 0.9849 - recall: 0.9849 - auc: 0.9989 - binary_accuracy: 0.9849 - binary_crossentropy: 0.0411 - val_loss: 0.0415 - val_tp: 142965.0000 - val_fp: 2231.0000 - val_tn: 142965.0000 - val_fn: 2231.0000 - val_acc: 0.0142 - val_precision: 0.9846 - val_recall: 0.9846 - val_auc: 0.9989 - val_binary_accuracy: 0.9846 - val_binary_crossentropy: 0.0415
# Epoch 75/100
# 662/662 [==============================] - 18s 27ms/step - loss: 0.0410 - tp: 333700.0000 - fp: 5088.0000 - tn: 333700.0000 - fn: 5088.0000 - acc: 0.0114 - precision: 0.9850 - recall: 0.9850 - auc: 0.9989 - binary_accuracy: 0.9850 - binary_crossentropy: 0.0410 - val_loss: 0.0416 - val_tp: 142966.0000 - val_fp: 2230.0000 - val_tn: 142966.0000 - val_fn: 2230.0000 - val_acc: 0.0196 - val_precision: 0.9846 - val_recall: 0.9846 - val_auc: 0.9989 - val_binary_accuracy: 0.9846 - val_binary_crossentropy: 0.0416
# Epoch 76/100
# 662/662 [==============================] - 18s 27ms/step - loss: 0.0409 - tp: 333713.0000 - fp: 5075.0000 - tn: 333713.0000 - fn: 5075.0000 - acc: 0.0120 - precision: 0.9850 - recall: 0.9850 - auc: 0.9989 - binary_accuracy: 0.9850 - binary_crossentropy: 0.0409 - val_loss: 0.0414 - val_tp: 142968.0000 - val_fp: 2228.0000 - val_tn: 142968.0000 - val_fn: 2228.0000 - val_acc: 0.0165 - val_precision: 0.9847 - val_recall: 0.9847 - val_auc: 0.9989 - val_binary_accuracy: 0.9847 - val_binary_crossentropy: 0.0414
# Epoch 77/100
# 662/662 [==============================] - 16s 25ms/step - loss: 0.0408 - tp: 333765.0000 - fp: 5023.0000 - tn: 333765.0000 - fn: 5023.0000 - acc: 0.0122 - precision: 0.9852 - recall: 0.9852 - auc: 0.9989 - binary_accuracy: 0.9852 - binary_crossentropy: 0.0408 - val_loss: 0.0413 - val_tp: 142974.0000 - val_fp: 2222.0000 - val_tn: 142974.0000 - val_fn: 2222.0000 - val_acc: 0.0179 - val_precision: 0.9847 - val_recall: 0.9847 - val_auc: 0.9989 - val_binary_accuracy: 0.9847 - val_binary_crossentropy: 0.0413
# Epoch 78/100
# 662/662 [==============================] - 17s 26ms/step - loss: 0.0410 - tp: 333714.0000 - fp: 5074.0000 - tn: 333714.0000 - fn: 5074.0000 - acc: 0.0123 - precision: 0.9850 - recall: 0.9850 - auc: 0.9988 - binary_accuracy: 0.9850 - binary_crossentropy: 0.0410 - val_loss: 0.0415 - val_tp: 142965.0000 - val_fp: 2231.0000 - val_tn: 142965.0000 - val_fn: 2231.0000 - val_acc: 0.0166 - val_precision: 0.9846 - val_recall: 0.9846 - val_auc: 0.9989 - val_binary_accuracy: 0.9846 - val_binary_crossentropy: 0.0415
# Epoch 79/100
# 662/662 [==============================] - 16s 25ms/step - loss: 0.0411 - tp: 333696.0000 - fp: 5092.0000 - tn: 333696.0000 - fn: 5092.0000 - acc: 0.0118 - precision: 0.9850 - recall: 0.9850 - auc: 0.9989 - binary_accuracy: 0.9850 - binary_crossentropy: 0.0411 - val_loss: 0.0414 - val_tp: 142965.0000 - val_fp: 2231.0000 - val_tn: 142965.0000 - val_fn: 2231.0000 - val_acc: 0.0166 - val_precision: 0.9846 - val_recall: 0.9846 - val_auc: 0.9989 - val_binary_accuracy: 0.9846 - val_binary_crossentropy: 0.0414
# Epoch 80/100
# 662/662 [==============================] - 17s 26ms/step - loss: 0.0407 - tp: 333737.0000 - fp: 5051.0000 - tn: 333737.0000 - fn: 5051.0000 - acc: 0.0119 - precision: 0.9851 - recall: 0.9851 - auc: 0.9989 - binary_accuracy: 0.9851 - binary_crossentropy: 0.0407 - val_loss: 0.0415 - val_tp: 142967.0000 - val_fp: 2229.0000 - val_tn: 142967.0000 - val_fn: 2229.0000 - val_acc: 0.0164 - val_precision: 0.9846 - val_recall: 0.9846 - val_auc: 0.9989 - val_binary_accuracy: 0.9846 - val_binary_crossentropy: 0.0415
# Epoch 81/100
# 662/662 [==============================] - 17s 26ms/step - loss: 0.0409 - tp: 333709.0000 - fp: 5079.0000 - tn: 333709.0000 - fn: 5079.0000 - acc: 0.0118 - precision: 0.9850 - recall: 0.9850 - auc: 0.9989 - binary_accuracy: 0.9850 - binary_crossentropy: 0.0409 - val_loss: 0.0415 - val_tp: 142968.0000 - val_fp: 2228.0000 - val_tn: 142968.0000 - val_fn: 2228.0000 - val_acc: 0.0161 - val_precision: 0.9847 - val_recall: 0.9847 - val_auc: 0.9989 - val_binary_accuracy: 0.9847 - val_binary_crossentropy: 0.0415
# Epoch 82/100
# 662/662 [==============================] - 20s 30ms/step - loss: 0.0410 - tp: 333733.0000 - fp: 5055.0000 - tn: 333733.0000 - fn: 5055.0000 - acc: 0.0117 - precision: 0.9851 - recall: 0.9851 - auc: 0.9989 - binary_accuracy: 0.9851 - binary_crossentropy: 0.0410 - val_loss: 0.0414 - val_tp: 142965.0000 - val_fp: 2231.0000 - val_tn: 142965.0000 - val_fn: 2231.0000 - val_acc: 0.0157 - val_precision: 0.9846 - val_recall: 0.9846 - val_auc: 0.9989 - val_binary_accuracy: 0.9846 - val_binary_crossentropy: 0.0414
# Epoch 83/100
# 662/662 [==============================] - 19s 28ms/step - loss: 0.0409 - tp: 333707.0000 - fp: 5081.0000 - tn: 333707.0000 - fn: 5081.0000 - acc: 0.0115 - precision: 0.9850 - recall: 0.9850 - auc: 0.9989 - binary_accuracy: 0.9850 - binary_crossentropy: 0.0409 - val_loss: 0.0416 - val_tp: 142957.0000 - val_fp: 2239.0000 - val_tn: 142957.0000 - val_fn: 2239.0000 - val_acc: 0.0161 - val_precision: 0.9846 - val_recall: 0.9846 - val_auc: 0.9989 - val_binary_accuracy: 0.9846 - val_binary_crossentropy: 0.0416
# Epoch 84/100
# 662/662 [==============================] - 20s 31ms/step - loss: 0.0410 - tp: 333667.0000 - fp: 5121.0000 - tn: 333667.0000 - fn: 5121.0000 - acc: 0.0119 - precision: 0.9849 - recall: 0.9849 - auc: 0.9989 - binary_accuracy: 0.9849 - binary_crossentropy: 0.0410 - val_loss: 0.0415 - val_tp: 142959.0000 - val_fp: 2237.0000 - val_tn: 142959.0000 - val_fn: 2237.0000 - val_acc: 0.0157 - val_precision: 0.9846 - val_recall: 0.9846 - val_auc: 0.9988 - val_binary_accuracy: 0.9846 - val_binary_crossentropy: 0.0415
# Epoch 85/100
# 662/662 [==============================] - 20s 31ms/step - loss: 0.0409 - tp: 333701.0000 - fp: 5087.0000 - tn: 333701.0000 - fn: 5087.0000 - acc: 0.0122 - precision: 0.9850 - recall: 0.9850 - auc: 0.9989 - binary_accuracy: 0.9850 - binary_crossentropy: 0.0409 - val_loss: 0.0415 - val_tp: 142966.0000 - val_fp: 2230.0000 - val_tn: 142966.0000 - val_fn: 2230.0000 - val_acc: 0.0178 - val_precision: 0.9846 - val_recall: 0.9846 - val_auc: 0.9989 - val_binary_accuracy: 0.9846 - val_binary_crossentropy: 0.0415
# Epoch 86/100
# 662/662 [==============================] - 19s 28ms/step - loss: 0.0407 - tp: 333716.0000 - fp: 5072.0000 - tn: 333716.0000 - fn: 5072.0000 - acc: 0.0126 - precision: 0.9850 - recall: 0.9850 - auc: 0.9989 - binary_accuracy: 0.9850 - binary_crossentropy: 0.0407 - val_loss: 0.0414 - val_tp: 142970.0000 - val_fp: 2226.0000 - val_tn: 142970.0000 - val_fn: 2226.0000 - val_acc: 0.0191 - val_precision: 0.9847 - val_recall: 0.9847 - val_auc: 0.9989 - val_binary_accuracy: 0.9847 - val_binary_crossentropy: 0.0414
# Epoch 87/100
# 662/662 [==============================] - 17s 26ms/step - loss: 0.0409 - tp: 333767.0000 - fp: 5021.0000 - tn: 333767.0000 - fn: 5021.0000 - acc: 0.0130 - precision: 0.9852 - recall: 0.9852 - auc: 0.9989 - binary_accuracy: 0.9852 - binary_crossentropy: 0.0409 - val_loss: 0.0415 - val_tp: 142967.0000 - val_fp: 2229.0000 - val_tn: 142967.0000 - val_fn: 2229.0000 - val_acc: 0.0186 - val_precision: 0.9846 - val_recall: 0.9846 - val_auc: 0.9989 - val_binary_accuracy: 0.9846 - val_binary_crossentropy: 0.0415
# Epoch 88/100
# 662/662 [==============================] - 22s 33ms/step - loss: 0.0408 - tp: 333755.0000 - fp: 5033.0000 - tn: 333755.0000 - fn: 5033.0000 - acc: 0.0132 - precision: 0.9851 - recall: 0.9851 - auc: 0.9989 - binary_accuracy: 0.9851 - binary_crossentropy: 0.0408 - val_loss: 0.0415 - val_tp: 142965.0000 - val_fp: 2231.0000 - val_tn: 142965.0000 - val_fn: 2231.0000 - val_acc: 0.0198 - val_precision: 0.9846 - val_recall: 0.9846 - val_auc: 0.9989 - val_binary_accuracy: 0.9846 - val_binary_crossentropy: 0.0415
# Epoch 89/100
# 662/662 [==============================] - 19s 29ms/step - loss: 0.0409 - tp: 333737.0000 - fp: 5051.0000 - tn: 333737.0000 - fn: 5051.0000 - acc: 0.0131 - precision: 0.9851 - recall: 0.9851 - auc: 0.9988 - binary_accuracy: 0.9851 - binary_crossentropy: 0.0409 - val_loss: 0.0414 - val_tp: 142968.0000 - val_fp: 2228.0000 - val_tn: 142968.0000 - val_fn: 2228.0000 - val_acc: 0.0190 - val_precision: 0.9847 - val_recall: 0.9847 - val_auc: 0.9989 - val_binary_accuracy: 0.9847 - val_binary_crossentropy: 0.0414
# Epoch 90/100
# 662/662 [==============================] - 19s 29ms/step - loss: 0.0409 - tp: 333722.0000 - fp: 5066.0000 - tn: 333722.0000 - fn: 5066.0000 - acc: 0.0129 - precision: 0.9850 - recall: 0.9850 - auc: 0.9989 - binary_accuracy: 0.9850 - binary_crossentropy: 0.0409 - val_loss: 0.0415 - val_tp: 142968.0000 - val_fp: 2228.0000 - val_tn: 142968.0000 - val_fn: 2228.0000 - val_acc: 0.0191 - val_precision: 0.9847 - val_recall: 0.9847 - val_auc: 0.9989 - val_binary_accuracy: 0.9847 - val_binary_crossentropy: 0.0415
# Epoch 91/100
# 662/662 [==============================] - 20s 30ms/step - loss: 0.0409 - tp: 333708.0000 - fp: 5080.0000 - tn: 333708.0000 - fn: 5080.0000 - acc: 0.0130 - precision: 0.9850 - recall: 0.9850 - auc: 0.9989 - binary_accuracy: 0.9850 - binary_crossentropy: 0.0409 - val_loss: 0.0415 - val_tp: 142967.0000 - val_fp: 2229.0000 - val_tn: 142967.0000 - val_fn: 2229.0000 - val_acc: 0.0182 - val_precision: 0.9846 - val_recall: 0.9846 - val_auc: 0.9988 - val_binary_accuracy: 0.9846 - val_binary_crossentropy: 0.0415
# Epoch 92/100
# 662/662 [==============================] - 25s 37ms/step - loss: 0.0411 - tp: 333706.0000 - fp: 5082.0000 - tn: 333706.0000 - fn: 5082.0000 - acc: 0.0128 - precision: 0.9850 - recall: 0.9850 - auc: 0.9989 - binary_accuracy: 0.9850 - binary_crossentropy: 0.0411 - val_loss: 0.0415 - val_tp: 142968.0000 - val_fp: 2228.0000 - val_tn: 142968.0000 - val_fn: 2228.0000 - val_acc: 0.0182 - val_precision: 0.9847 - val_recall: 0.9847 - val_auc: 0.9989 - val_binary_accuracy: 0.9847 - val_binary_crossentropy: 0.0415
# Epoch 93/100
# 662/662 [==============================] - 66s 99ms/step - loss: 0.0409 - tp: 333735.0000 - fp: 5053.0000 - tn: 333735.0000 - fn: 5053.0000 - acc: 0.0127 - precision: 0.9851 - recall: 0.9851 - auc: 0.9989 - binary_accuracy: 0.9851 - binary_crossentropy: 0.0409 - val_loss: 0.0414 - val_tp: 142967.0000 - val_fp: 2229.0000 - val_tn: 142967.0000 - val_fn: 2229.0000 - val_acc: 0.0179 - val_precision: 0.9846 - val_recall: 0.9846 - val_auc: 0.9989 - val_binary_accuracy: 0.9846 - val_binary_crossentropy: 0.0414
# Epoch 94/100
# 662/662 [==============================] - 65s 99ms/step - loss: 0.0407 - tp: 333751.0000 - fp: 5037.0000 - tn: 333751.0000 - fn: 5037.0000 - acc: 0.0128 - precision: 0.9851 - recall: 0.9851 - auc: 0.9989 - binary_accuracy: 0.9851 - binary_crossentropy: 0.0407 - val_loss: 0.0414 - val_tp: 142968.0000 - val_fp: 2228.0000 - val_tn: 142968.0000 - val_fn: 2228.0000 - val_acc: 0.0185 - val_precision: 0.9847 - val_recall: 0.9847 - val_auc: 0.9989 - val_binary_accuracy: 0.9847 - val_binary_crossentropy: 0.0414
# Epoch 95/100
# 662/662 [==============================] - 59s 89ms/step - loss: 0.0408 - tp: 333752.0000 - fp: 5036.0000 - tn: 333752.0000 - fn: 5036.0000 - acc: 0.0130 - precision: 0.9851 - recall: 0.9851 - auc: 0.9989 - binary_accuracy: 0.9851 - binary_crossentropy: 0.0408 - val_loss: 0.0414 - val_tp: 142969.0000 - val_fp: 2227.0000 - val_tn: 142969.0000 - val_fn: 2227.0000 - val_acc: 0.0187 - val_precision: 0.9847 - val_recall: 0.9847 - val_auc: 0.9989 - val_binary_accuracy: 0.9847 - val_binary_crossentropy: 0.0414
# Epoch 96/100
# 662/662 [==============================] - 52s 78ms/step - loss: 0.0410 - tp: 333746.0000 - fp: 5042.0000 - tn: 333746.0000 - fn: 5042.0000 - acc: 0.0125 - precision: 0.9851 - recall: 0.9851 - auc: 0.9988 - binary_accuracy: 0.9851 - binary_crossentropy: 0.0410 - val_loss: 0.0414 - val_tp: 142968.0000 - val_fp: 2228.0000 - val_tn: 142968.0000 - val_fn: 2228.0000 - val_acc: 0.0176 - val_precision: 0.9847 - val_recall: 0.9847 - val_auc: 0.9989 - val_binary_accuracy: 0.9847 - val_binary_crossentropy: 0.0414
# Epoch 97/100
# 662/662 [==============================] - 59s 90ms/step - loss: 0.0411 - tp: 333715.0000 - fp: 5073.0000 - tn: 333715.0000 - fn: 5073.0000 - acc: 0.0127 - precision: 0.9850 - recall: 0.9850 - auc: 0.9989 - binary_accuracy: 0.9850 - binary_crossentropy: 0.0411 - val_loss: 0.0414 - val_tp: 142971.0000 - val_fp: 2225.0000 - val_tn: 142971.0000 - val_fn: 2225.0000 - val_acc: 0.0180 - val_precision: 0.9847 - val_recall: 0.9847 - val_auc: 0.9988 - val_binary_accuracy: 0.9847 - val_binary_crossentropy: 0.0414
# Epoch 98/100
# 662/662 [==============================] - 55s 83ms/step - loss: 0.0409 - tp: 333690.0000 - fp: 5098.0000 - tn: 333690.0000 - fn: 5098.0000 - acc: 0.0125 - precision: 0.9850 - recall: 0.9850 - auc: 0.9989 - binary_accuracy: 0.9850 - binary_crossentropy: 0.0409 - val_loss: 0.0414 - val_tp: 142970.0000 - val_fp: 2226.0000 - val_tn: 142970.0000 - val_fn: 2226.0000 - val_acc: 0.0178 - val_precision: 0.9847 - val_recall: 0.9847 - val_auc: 0.9988 - val_binary_accuracy: 0.9847 - val_binary_crossentropy: 0.0414
# Epoch 99/100
# 662/662 [==============================] - 56s 84ms/step - loss: 0.0407 - tp: 333752.0000 - fp: 5036.0000 - tn: 333752.0000 - fn: 5036.0000 - acc: 0.0125 - precision: 0.9851 - recall: 0.9851 - auc: 0.9989 - binary_accuracy: 0.9851 - binary_crossentropy: 0.0407 - val_loss: 0.0414 - val_tp: 142969.0000 - val_fp: 2227.0000 - val_tn: 142969.0000 - val_fn: 2227.0000 - val_acc: 0.0168 - val_precision: 0.9847 - val_recall: 0.9847 - val_auc: 0.9989 - val_binary_accuracy: 0.9847 - val_binary_crossentropy: 0.0414
# Epoch 100/100
# 662/662 [==============================] - 46s 70ms/step - loss: 0.0409 - tp: 333724.0000 - fp: 5064.0000 - tn: 333724.0000 - fn: 5064.0000 - acc: 0.0124 - precision: 0.9851 - recall: 0.9851 - auc: 0.9989 - binary_accuracy: 0.9851 - binary_crossentropy: 0.0409 - val_loss: 0.0414 - val_tp: 142971.0000 - val_fp: 2225.0000 - val_tn: 142971.0000 - val_fn: 2225.0000 - val_acc: 0.0177 - val_precision: 0.9847 - val_recall: 0.9847 - val_auc: 0.9989 - val_binary_accuracy: 0.9847 - val_binary_crossentropy: 0.0414

# %%
results  = model.evaluate(X_test, y_test, verbose=1)
modelmetric.getTrainMetricValue(model, results)
# Out:
# 6482/6482 [==============================] - 276s 43ms/step - loss: 0.0415 - tp: 204281.0000 - fp: 3141.0000 - tn: 204281.0000 - fn: 3141.0000 - acc: 0.0173 - precision: 0.9849 - recall: 0.9849 - auc: 0.9989 - binary_accuracy: 0.9849 - binary_crossentropy: 0.0415
# loss :  0.04151104390621185
# tp :  204281.0
# fp :  3141.0
# tn :  204281.0
# fn :  3141.0
# acc :  0.017331816256046295
# precision :  0.9848569631576538
# recall :  0.9848569631576538
# auc :  0.9988895058631897
# binary_accuracy :  0.9848569631576538
# binary_crossentropy :  0.04151104390621185

# %%
y_pred = model.predict(X_test)
y_class = np.argmax(y_pred, axis=1)
y_label = np.argmax(y_test, axis=1)
modelmetric.confusion_matrix(y_label, y_class)
modelmetric.eva_metric(y_label, y_class)
# Out:
# TrueNegatives result:  128768.0
# TruePositives result:  75513.0
# FalseNegatives result:  131.0
# FalsePositives result:  3010.0
# Recall result:  0.9982682
# Precision result:  0.9616673

# %%
mf = ModelFigre("../../model_record/CPU/", dir_name, model_)
mf.loss_graph()
mf.recall_graph()
mf.precision_graph()
mf.cross_entropy_graph()
# fig.save_model(net,dir_name)
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
mf.lr_graph()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
model.save('../../model_record/CPU/'+dir_name+'/model/model.h5')
