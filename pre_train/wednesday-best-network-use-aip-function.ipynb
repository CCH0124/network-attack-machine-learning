# %% [markdown]
# ## 20200923-181126-network-RMSprop

# %%
import tensorflow as tf
import numpy as np
import sys
sys.path.append('../')
import utils.data_preprocess as preprocess
from utils.model_metrics import ModelMetric
from utils.mode_figure import ModelFigre
import datetime
from utils.model_callback import step_decay, exp_decay, MyStopTrainCallBack

# %%
modelmetric = ModelMetric()

# %%
from tensorflow.keras.layers import LSTM, Bidirectional, BatchNormalization, GaussianNoise, Flatten, Dense, Input, Activation
from tensorflow.keras import Model
dos_input = Input(shape=(1, 77))
forward_layer_one = LSTM(64, kernel_constraint=tf.keras.constraints.MaxNorm(max_value=4) , recurrent_constraint=tf.keras.constraints.MaxNorm(max_value=4), return_sequences=True)
backward_layer_one = LSTM(64, kernel_constraint=tf.keras.constraints.MaxNorm(max_value=4) , recurrent_constraint=tf.keras.constraints.MaxNorm(max_value=4), return_sequences=True , go_backwards=True)
bi_one = Bidirectional(forward_layer_one, backward_layer=backward_layer_one, name='bi_one')(dos_input)

noise_one = GaussianNoise(0.5)(bi_one)

bn_one = BatchNormalization()(noise_one)

forward_layer_two = LSTM(32, return_sequences=True)
backward_layer_two = LSTM(32, return_sequences=True, go_backwards=True)
bi_two = Bidirectional(forward_layer_two, backward_layer=backward_layer_two, name='bi_two')(bn_one)

bn_two = BatchNormalization()(bi_two)

forward_layer_three = LSTM(16,)
backward_layer_three = LSTM(16, go_backwards=True)
bi_three = Bidirectional(forward_layer_three, backward_layer=backward_layer_three, name='bi_three')(bn_two)

bn_three = BatchNormalization()(bi_three)

flatten_one = Flatten()(bn_three)

dense_four = Dense(16, kernel_constraint=tf.keras.constraints.MaxNorm(max_value=4), name='dense_three')(flatten_one)
noise_two = GaussianNoise(0.5)(dense_four)
avtivation_four = Activation(tf.nn.relu6, name='dense_four_activation')(noise_two)

bn_four = BatchNormalization()(avtivation_four)

dense = Dense(2, name='classification')(bn_four)
output_res = Activation(tf.nn.softmax, name='classifi')(dense)

model = Model(inputs=dos_input, outputs=output_res)

# algorithm = tf.keras.optimizers.RMSprop(learning_rate=0.001, rho=0.9, clipvalue=0.3, momentum=0.9, epsilon=1e-07, decay= 1e-06, centered=False, name='RMSprop')
algorithm = tf.keras.optimizers.SGD(learning_rate=0.0129, momentum=0.99, clipvalue=0.3, nesterov=True, name='SGD')

model.compile(optimizer=algorithm, loss='binary_crossentropy', metrics=modelmetric.metric('binary_crossentropy')) # categorical_crossentropycategorical_crossentropy

# %%
from tensorflow.keras import callbacks
dir_name = datetime.datetime.now().strftime("Best-%Y%m%d-%H%M%S-SGD")

logdir = os.path.join("../tensorboard", dir_name)
tensorboard_callback = callbacks.TensorBoard(logdir, histogram_freq=1)
lrate = callbacks.LearningRateScheduler(step_decay)
csv_log = tf.keras.callbacks.CSVLogger('../model_record/'+dir_name+"/log", separator=',', append=False)
if not os.path.isdir('../model_record/'+dir_name):
    os.mkdir('../model_record/'+dir_name)
    os.mkdir('../model_record/'+dir_name+'/model')
# stop_train = MyStopTrainCallBack()
# callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
pre = preprocess.preprocess("D:/DataSet/CICIDS2017/CSV/Wednesday-workingHours.pcap_ISCX.csv", labelColumnName='Label', depth=2)
X_train, X_test, y_train, y_test = pre.preprocessing()
X_train = tf.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = tf.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
import numpy as np
model_ = model.fit(X_train, y_train, epochs=100, batch_size=512, validation_split=0.3, callbacks=[tensorboard_callback, csv_log, lrate], verbose=1) # lrate
# Out:
#  val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0407 - lr: 0.0016
# Epoch 64/100
# 662/662 [==============================] - 18s 27ms/step - loss: 0.0421 - tp: 333606.0000 - fp: 5182.0000 - tn: 333606.0000 - fn: 5182.0000 - acc: 0.0012 - precision: 0.9847 - recall: 0.9847 - auc: 0.9988 - binary_accuracy: 0.9847 - binary_crossentropy: 0.0421 - val_loss: 0.0407 - val_tp: 143071.0000 - val_fp: 2125.0000 - val_tn: 143071.0000 - val_fn: 2125.0000 - val_acc: 0.0010 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0407 - lr: 0.0016
# Epoch 65/100
# 662/662 [==============================] - 17s 25ms/step - loss: 0.0420 - tp: 333646.0000 - fp: 5142.0000 - tn: 333646.0000 - fn: 5142.0000 - acc: 0.0014 - precision: 0.9848 - recall: 0.9848 - auc: 0.9988 - binary_accuracy: 0.9848 - binary_crossentropy: 0.0420 - val_loss: 0.0407 - val_tp: 143075.0000 - val_fp: 2121.0000 - val_tn: 143075.0000 - val_fn: 2121.0000 - val_acc: 0.0010 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0407 - lr: 0.0016
# Epoch 66/100
# 662/662 [==============================] - 16s 24ms/step - loss: 0.0421 - tp: 333597.0000 - fp: 5191.0000 - tn: 333597.0000 - fn: 5191.0000 - acc: 0.0011 - precision: 0.9847 - recall: 0.9847 - auc: 0.9988 - binary_accuracy: 0.9847 - binary_crossentropy: 0.0421 - val_loss: 0.0406 - val_tp: 143081.0000 - val_fp: 2115.0000 - val_tn: 143081.0000 - val_fn: 2115.0000 - val_acc: 9.8488e-04 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0406 - lr: 0.0016
# Epoch 67/100
# 662/662 [==============================] - 16s 24ms/step - loss: 0.0419 - tp: 333597.0000 - fp: 5191.0000 - tn: 333597.0000 - fn: 5191.0000 - acc: 0.0013 - precision: 0.9847 - recall: 0.9847 - auc: 0.9988 - binary_accuracy: 0.9847 - binary_crossentropy: 0.0419 - val_loss: 0.0408 - val_tp: 143050.0000 - val_fp: 2146.0000 - val_tn: 143050.0000 - val_fn: 2146.0000 - val_acc: 0.0012 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9989 - val_binary_accuracy: 0.9852 - val_binary_crossentropy: 0.0408 - lr: 0.0016
# Epoch 68/100
# 662/662 [==============================] - 16s 24ms/step - loss: 0.0420 - tp: 333601.0000 - fp: 5187.0000 - tn: 333601.0000 - fn: 5187.0000 - acc: 0.0013 - precision: 0.9847 - recall: 0.9847 - auc: 0.9988 - binary_accuracy: 0.9847 - binary_crossentropy: 0.0420 - val_loss: 0.0408 - val_tp: 143054.0000 - val_fp: 2142.0000 - val_tn: 143054.0000 - val_fn: 2142.0000 - val_acc: 0.0011 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9989 - val_binary_accuracy: 0.9852 - val_binary_crossentropy: 0.0408 - lr: 0.0016
# Epoch 69/100
# 662/662 [==============================] - 17s 26ms/step - loss: 0.0420 - tp: 333595.0000 - fp: 5193.0000 - tn: 333595.0000 - fn: 5193.0000 - acc: 0.0013 - precision: 0.9847 - recall: 0.9847 - auc: 0.9988 - binary_accuracy: 0.9847 - binary_crossentropy: 0.0420 - val_loss: 0.0407 - val_tp: 143081.0000 - val_fp: 2115.0000 - val_tn: 143081.0000 - val_fn: 2115.0000 - val_acc: 0.0011 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0407 - lr: 0.0016
# Epoch 70/100
# 662/662 [==============================] - 19s 29ms/step - loss: 0.0421 - tp: 333598.0000 - fp: 5190.0000 - tn: 333598.0000 - fn: 5190.0000 - acc: 0.0013 - precision: 0.9847 - recall: 0.9847 - auc: 0.9988 - binary_accuracy: 0.9847 - binary_crossentropy: 0.0421 - val_loss: 0.0407 - val_tp: 143039.0000 - val_fp: 2157.0000 - val_tn: 143039.0000 - val_fn: 2157.0000 - val_acc: 0.0011 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0407 - lr: 7.8125e-04
# Epoch 71/100
# 662/662 [==============================] - 18s 27ms/step - loss: 0.0420 - tp: 333605.0000 - fp: 5183.0000 - tn: 333605.0000 - fn: 5183.0000 - acc: 0.0014 - precision: 0.9847 - recall: 0.9847 - auc: 0.9988 - binary_accuracy: 0.9847 - binary_crossentropy: 0.0420 - val_loss: 0.0407 - val_tp: 143052.0000 - val_fp: 2144.0000 - val_tn: 143052.0000 - val_fn: 2144.0000 - val_acc: 0.0011 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9989 - val_binary_accuracy: 0.9852 - val_binary_crossentropy: 0.0407 - lr: 7.8125e-04
# Epoch 72/100
# 662/662 [==============================] - 19s 28ms/step - loss: 0.0419 - tp: 333623.0000 - fp: 5165.0000 - tn: 333623.0000 - fn: 5165.0000 - acc: 0.0016 - precision: 0.9848 - recall: 0.9848 - auc: 0.9988 - binary_accuracy: 0.9848 - binary_crossentropy: 0.0419 - val_loss: 0.0407 - val_tp: 143071.0000 - val_fp: 2125.0000 - val_tn: 143071.0000 - val_fn: 2125.0000 - val_acc: 0.0012 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0407 - lr: 7.8125e-04
# Epoch 73/100
# 662/662 [==============================] - 18s 28ms/step - loss: 0.0419 - tp: 333606.0000 - fp: 5182.0000 - tn: 333606.0000 - fn: 5182.0000 - acc: 0.0018 - precision: 0.9847 - recall: 0.9847 - auc: 0.9988 - binary_accuracy: 0.9847 - binary_crossentropy: 0.0419 - val_loss: 0.0406 - val_tp: 143083.0000 - val_fp: 2113.0000 - val_tn: 143083.0000 - val_fn: 2113.0000 - val_acc: 0.0012 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0406 - lr: 7.8125e-04
# Epoch 74/100
# 662/662 [==============================] - 19s 29ms/step - loss: 0.0419 - tp: 333655.0000 - fp: 5133.0000 - tn: 333655.0000 - fn: 5133.0000 - acc: 0.0017 - precision: 0.9848 - recall: 0.9848 - auc: 0.9988 - binary_accuracy: 0.9848 - binary_crossentropy: 0.0419 - val_loss: 0.0407 - val_tp: 143070.0000 - val_fp: 2126.0000 - val_tn: 143070.0000 - val_fn: 2126.0000 - val_acc: 0.0012 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0407 - lr: 7.8125e-04
# Epoch 75/100
# 662/662 [==============================] - 21s 32ms/step - loss: 0.0417 - tp: 333671.0000 - fp: 5117.0000 - tn: 333671.0000 - fn: 5117.0000 - acc: 0.0018 - precision: 0.9849 - recall: 0.9849 - auc: 0.9988 - binary_accuracy: 0.9849 - binary_crossentropy: 0.0417 - val_loss: 0.0406 - val_tp: 143083.0000 - val_fp: 2113.0000 - val_tn: 143083.0000 - val_fn: 2113.0000 - val_acc: 0.0012 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0406 - lr: 7.8125e-04
# Epoch 76/100
# 662/662 [==============================] - 45s 68ms/step - loss: 0.0420 - tp: 333631.0000 - fp: 5157.0000 - tn: 333631.0000 - fn: 5157.0000 - acc: 0.0018 - precision: 0.9848 - recall: 0.9848 - auc: 0.9988 - binary_accuracy: 0.9848 - binary_crossentropy: 0.0420 - val_loss: 0.0406 - val_tp: 143079.0000 - val_fp: 2117.0000 - val_tn: 143079.0000 - val_fn: 2117.0000 - val_acc: 0.0012 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0406 - lr: 7.8125e-04
# Epoch 77/100
# 662/662 [==============================] - 45s 68ms/step - loss: 0.0420 - tp: 333596.0000 - fp: 5192.0000 - tn: 333596.0000 - fn: 5192.0000 - acc: 0.0017 - precision: 0.9847 - recall: 0.9847 - auc: 0.9988 - binary_accuracy: 0.9847 - binary_crossentropy: 0.0420 - val_loss: 0.0407 - val_tp: 143054.0000 - val_fp: 2142.0000 - val_tn: 143054.0000 - val_fn: 2142.0000 - val_acc: 0.0012 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9989 - val_binary_accuracy: 0.9852 - val_binary_crossentropy: 0.0407 - lr: 7.8125e-04
# Epoch 78/100
# 662/662 [==============================] - 48s 72ms/step - loss: 0.0420 - tp: 333619.0000 - fp: 5169.0000 - tn: 333619.0000 - fn: 5169.0000 - acc: 0.0017 - precision: 0.9847 - recall: 0.9847 - auc: 0.9988 - binary_accuracy: 0.9847 - binary_crossentropy: 0.0420 - val_loss: 0.0406 - val_tp: 143076.0000 - val_fp: 2120.0000 - val_tn: 143076.0000 - val_fn: 2120.0000 - val_acc: 0.0012 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0406 - lr: 7.8125e-04
# Epoch 79/100
# 662/662 [==============================] - 44s 67ms/step - loss: 0.0420 - tp: 333620.0000 - fp: 5168.0000 - tn: 333620.0000 - fn: 5168.0000 - acc: 0.0018 - precision: 0.9847 - recall: 0.9847 - auc: 0.9988 - binary_accuracy: 0.9847 - binary_crossentropy: 0.0420 - val_loss: 0.0406 - val_tp: 143079.0000 - val_fp: 2117.0000 - val_tn: 143079.0000 - val_fn: 2117.0000 - val_acc: 0.0012 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0406 - lr: 7.8125e-04
# Epoch 80/100
# 662/662 [==============================] - 48s 73ms/step - loss: 0.0421 - tp: 333619.0000 - fp: 5169.0000 - tn: 333619.0000 - fn: 5169.0000 - acc: 0.0017 - precision: 0.9847 - recall: 0.9847 - auc: 0.9988 - binary_accuracy: 0.9847 - binary_crossentropy: 0.0421 - val_loss: 0.0406 - val_tp: 143083.0000 - val_fp: 2113.0000 - val_tn: 143083.0000 - val_fn: 2113.0000 - val_acc: 0.0012 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0406 - lr: 3.9063e-04
# Epoch 81/100
# 662/662 [==============================] - 49s 73ms/step - loss: 0.0418 - tp: 333635.0000 - fp: 5153.0000 - tn: 333635.0000 - fn: 5153.0000 - acc: 0.0018 - precision: 0.9848 - recall: 0.9848 - auc: 0.9988 - binary_accuracy: 0.9848 - binary_crossentropy: 0.0418 - val_loss: 0.0405 - val_tp: 143084.0000 - val_fp: 2112.0000 - val_tn: 143084.0000 - val_fn: 2112.0000 - val_acc: 0.0012 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9989 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0405 - lr: 3.9063e-04
# Epoch 82/100
# 662/662 [==============================] - 53s 80ms/step - loss: 0.0420 - tp: 333634.0000 - fp: 5154.0000 - tn: 333634.0000 - fn: 5154.0000 - acc: 0.0018 - precision: 0.9848 - recall: 0.9848 - auc: 0.9988 - binary_accuracy: 0.9848 - binary_crossentropy: 0.0420 - val_loss: 0.0406 - val_tp: 143070.0000 - val_fp: 2126.0000 - val_tn: 143070.0000 - val_fn: 2126.0000 - val_acc: 0.0012 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0406 - lr: 3.9063e-04
# Epoch 83/100
# 662/662 [==============================] - 47s 70ms/step - loss: 0.0418 - tp: 333646.0000 - fp: 5142.0000 - tn: 333646.0000 - fn: 5142.0000 - acc: 0.0018 - precision: 0.9848 - recall: 0.9848 - auc: 0.9988 - binary_accuracy: 0.9848 - binary_crossentropy: 0.0418 - val_loss: 0.0407 - val_tp: 143070.0000 - val_fp: 2126.0000 - val_tn: 143070.0000 - val_fn: 2126.0000 - val_acc: 0.0012 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0407 - lr: 3.9063e-04
# Epoch 84/100
# 662/662 [==============================] - 44s 67ms/step - loss: 0.0418 - tp: 333671.0000 - fp: 5117.0000 - tn: 333671.0000 - fn: 5117.0000 - acc: 0.0019 - precision: 0.9849 - recall: 0.9849 - auc: 0.9988 - binary_accuracy: 0.9849 - binary_crossentropy: 0.0418 - val_loss: 0.0406 - val_tp: 143078.0000 - val_fp: 2118.0000 - val_tn: 143078.0000 - val_fn: 2118.0000 - val_acc: 0.0013 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0406 - lr: 3.9063e-04
# Epoch 85/100
# 662/662 [==============================] - 39s 59ms/step - loss: 0.0422 - tp: 333621.0000 - fp: 5167.0000 - tn: 333621.0000 - fn: 5167.0000 - acc: 0.0019 - precision: 0.9847 - recall: 0.9847 - auc: 0.9988 - binary_accuracy: 0.9847 - binary_crossentropy: 0.0422 - val_loss: 0.0406 - val_tp: 143084.0000 - val_fp: 2112.0000 - val_tn: 143084.0000 - val_fn: 2112.0000 - val_acc: 0.0012 - val_precision: 0.9855 - val_recall: 0.9855 - val_auc: 0.9989 - val_binary_accuracy: 0.9855 - val_binary_crossentropy: 0.0406 - lr: 3.9063e-04
# Epoch 86/100
# 662/662 [==============================] - 46s 70ms/step - loss: 0.0418 - tp: 333655.0000 - fp: 5133.0000 - tn: 333655.0000 - fn: 5133.0000 - acc: 0.0019 - precision: 0.9848 - recall: 0.9848 - auc: 0.9988 - binary_accuracy: 0.9848 - binary_crossentropy: 0.0418 - val_loss: 0.0407 - val_tp: 143070.0000 - val_fp: 2126.0000 - val_tn: 143070.0000 - val_fn: 2126.0000 - val_acc: 0.0012 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0407 - lr: 3.9063e-04
# Epoch 87/100
# 662/662 [==============================] - 47s 71ms/step - loss: 0.0420 - tp: 333629.0000 - fp: 5159.0000 - tn: 333629.0000 - fn: 5159.0000 - acc: 0.0017 - precision: 0.9848 - recall: 0.9848 - auc: 0.9988 - binary_accuracy: 0.9848 - binary_crossentropy: 0.0420 - val_loss: 0.0407 - val_tp: 143069.0000 - val_fp: 2127.0000 - val_tn: 143069.0000 - val_fn: 2127.0000 - val_acc: 0.0012 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0407 - lr: 3.9063e-04
# Epoch 88/100
# 662/662 [==============================] - 50s 76ms/step - loss: 0.0417 - tp: 333665.0000 - fp: 5123.0000 - tn: 333665.0000 - fn: 5123.0000 - acc: 0.0019 - precision: 0.9849 - recall: 0.9849 - auc: 0.9988 - binary_accuracy: 0.9849 - binary_crossentropy: 0.0417 - val_loss: 0.0406 - val_tp: 143083.0000 - val_fp: 2113.0000 - val_tn: 143083.0000 - val_fn: 2113.0000 - val_acc: 0.0012 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0406 - lr: 3.9063e-04
# Epoch 89/100
# 662/662 [==============================] - 50s 75ms/step - loss: 0.0421 - tp: 333607.0000 - fp: 5181.0000 - tn: 333607.0000 - fn: 5181.0000 - acc: 0.0020 - precision: 0.9847 - recall: 0.9847 - auc: 0.9988 - binary_accuracy: 0.9847 - binary_crossentropy: 0.0421 - val_loss: 0.0407 - val_tp: 143068.0000 - val_fp: 2128.0000 - val_tn: 143068.0000 - val_fn: 2128.0000 - val_acc: 0.0012 - val_precision: 0.9853 - val_recall: 0.9853 - val_auc: 0.9989 - val_binary_accuracy: 0.9853 - val_binary_crossentropy: 0.0407 - lr: 3.9063e-04
# Epoch 90/100
# 662/662 [==============================] - 42s 63ms/step - loss: 0.0423 - tp: 333596.0000 - fp: 5192.0000 - tn: 333596.0000 - fn: 5192.0000 - acc: 0.0018 - precision: 0.9847 - recall: 0.9847 - auc: 0.9988 - binary_accuracy: 0.9847 - binary_crossentropy: 0.0423 - val_loss: 0.0407 - val_tp: 143062.0000 - val_fp: 2134.0000 - val_tn: 143062.0000 - val_fn: 2134.0000 - val_acc: 0.0012 - val_precision: 0.9853 - val_recall: 0.9853 - val_auc: 0.9989 - val_binary_accuracy: 0.9853 - val_binary_crossentropy: 0.0407 - lr: 1.9531e-04
# Epoch 91/100
# 662/662 [==============================] - 49s 74ms/step - loss: 0.0419 - tp: 333645.0000 - fp: 5143.0000 - tn: 333645.0000 - fn: 5143.0000 - acc: 0.0018 - precision: 0.9848 - recall: 0.9848 - auc: 0.9988 - binary_accuracy: 0.9848 - binary_crossentropy: 0.0419 - val_loss: 0.0407 - val_tp: 143070.0000 - val_fp: 2126.0000 - val_tn: 143070.0000 - val_fn: 2126.0000 - val_acc: 0.0012 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0407 - lr: 1.9531e-04
# Epoch 92/100
# 662/662 [==============================] - 52s 78ms/step - loss: 0.0422 - tp: 333606.0000 - fp: 5182.0000 - tn: 333606.0000 - fn: 5182.0000 - acc: 0.0017 - precision: 0.9847 - recall: 0.9847 - auc: 0.9988 - binary_accuracy: 0.9847 - binary_crossentropy: 0.0422 - val_loss: 0.0406 - val_tp: 143077.0000 - val_fp: 2119.0000 - val_tn: 143077.0000 - val_fn: 2119.0000 - val_acc: 0.0011 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0406 - lr: 1.9531e-04
# Epoch 93/100
# 662/662 [==============================] - 46s 70ms/step - loss: 0.0420 - tp: 333637.0000 - fp: 5151.0000 - tn: 333637.0000 - fn: 5151.0000 - acc: 0.0018 - precision: 0.9848 - recall: 0.9848 - auc: 0.9988 - binary_accuracy: 0.9848 - binary_crossentropy: 0.0420 - val_loss: 0.0407 - val_tp: 143070.0000 - val_fp: 2126.0000 - val_tn: 143070.0000 - val_fn: 2126.0000 - val_acc: 0.0012 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0407 - lr: 1.9531e-04
# Epoch 94/100
# 662/662 [==============================] - 49s 74ms/step - loss: 0.0418 - tp: 333642.0000 - fp: 5146.0000 - tn: 333642.0000 - fn: 5146.0000 - acc: 0.0017 - precision: 0.9848 - recall: 0.9848 - auc: 0.9988 - binary_accuracy: 0.9848 - binary_crossentropy: 0.0418 - val_loss: 0.0407 - val_tp: 143070.0000 - val_fp: 2126.0000 - val_tn: 143070.0000 - val_fn: 2126.0000 - val_acc: 0.0012 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0407 - lr: 1.9531e-04
# Epoch 95/100
# 662/662 [==============================] - 51s 77ms/step - loss: 0.0417 - tp: 333645.0000 - fp: 5143.0000 - tn: 333645.0000 - fn: 5143.0000 - acc: 0.0018 - precision: 0.9848 - recall: 0.9848 - auc: 0.9988 - binary_accuracy: 0.9848 - binary_crossentropy: 0.0417 - val_loss: 0.0406 - val_tp: 143082.0000 - val_fp: 2114.0000 - val_tn: 143082.0000 - val_fn: 2114.0000 - val_acc: 0.0012 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0406 - lr: 1.9531e-04
# Epoch 96/100
# 662/662 [==============================] - 41s 62ms/step - loss: 0.0422 - tp: 333598.0000 - fp: 5190.0000 - tn: 333598.0000 - fn: 5190.0000 - acc: 0.0018 - precision: 0.9847 - recall: 0.9847 - auc: 0.9988 - binary_accuracy: 0.9847 - binary_crossentropy: 0.0422 - val_loss: 0.0407 - val_tp: 143069.0000 - val_fp: 2127.0000 - val_tn: 143069.0000 - val_fn: 2127.0000 - val_acc: 0.0012 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0407 - lr: 1.9531e-04
# Epoch 97/100
# 662/662 [==============================] - 43s 65ms/step - loss: 0.0418 - tp: 333625.0000 - fp: 5163.0000 - tn: 333625.0000 - fn: 5163.0000 - acc: 0.0018 - precision: 0.9848 - recall: 0.9848 - auc: 0.9988 - binary_accuracy: 0.9848 - binary_crossentropy: 0.0418 - val_loss: 0.0407 - val_tp: 143065.0000 - val_fp: 2131.0000 - val_tn: 143065.0000 - val_fn: 2131.0000 - val_acc: 0.0012 - val_precision: 0.9853 - val_recall: 0.9853 - val_auc: 0.9989 - val_binary_accuracy: 0.9853 - val_binary_crossentropy: 0.0407 - lr: 1.9531e-04
# Epoch 98/100
# 662/662 [==============================] - 36s 54ms/step - loss: 0.0420 - tp: 333626.0000 - fp: 5162.0000 - tn: 333626.0000 - fn: 5162.0000 - acc: 0.0018 - precision: 0.9848 - recall: 0.9848 - auc: 0.9988 - binary_accuracy: 0.9848 - binary_crossentropy: 0.0420 - val_loss: 0.0407 - val_tp: 143075.0000 - val_fp: 2121.0000 - val_tn: 143075.0000 - val_fn: 2121.0000 - val_acc: 0.0012 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0407 - lr: 1.9531e-04
# Epoch 99/100
# 662/662 [==============================] - 51s 77ms/step - loss: 0.0419 - tp: 333631.0000 - fp: 5157.0000 - tn: 333631.0000 - fn: 5157.0000 - acc: 0.0018 - precision: 0.9848 - recall: 0.9848 - auc: 0.9988 - binary_accuracy: 0.9848 - binary_crossentropy: 0.0419 - val_loss: 0.0407 - val_tp: 143075.0000 - val_fp: 2121.0000 - val_tn: 143075.0000 - val_fn: 2121.0000 - val_acc: 0.0012 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0407 - lr: 1.9531e-04
# Epoch 100/100
# 662/662 [==============================] - 43s 66ms/step - loss: 0.0419 - tp: 333650.0000 - fp: 5138.0000 - tn: 333650.0000 - fn: 5138.0000 - acc: 0.0018 - precision: 0.9848 - recall: 0.9848 - auc: 0.9988 - binary_accuracy: 0.9848 - binary_crossentropy: 0.0419 - val_loss: 0.0406 - val_tp: 143077.0000 - val_fp: 2119.0000 - val_tn: 143077.0000 - val_fn: 2119.0000 - val_acc: 0.0012 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0406 - lr: 9.7656e-05

# %%
results  = model.evaluate(X_test, y_test, verbose=1)
modelmetric.getTrainMetricValue(model, results)
# Out:
# 6482/6482 [==============================] - 184s 28ms/step - loss: 0.0404 - tp: 204341.0000 - fp: 3081.0000 - tn: 204341.0000 - fn: 3081.0000 - acc: 0.0011 - precision: 0.9851 - recall: 0.9851 - auc: 0.9990 - binary_accuracy: 0.9851 - binary_crossentropy: 0.0404
# loss :  0.040394630283117294
# tp :  204341.0
# fp :  3081.0
# tn :  204341.0
# fn :  3081.0
# acc :  0.001053408021107316
# precision :  0.9851462244987488
# recall :  0.9851462244987488
# auc :  0.9989821314811707
# binary_accuracy :  0.9851462244987488
# binary_crossentropy :  0.040394630283117294

# %%
y_pred = model.predict(X_test)
y_class = np.argmax(y_pred, axis=1)
y_label = np.argmax(y_test, axis=1)
modelmetric.confusion_matrix(y_label, y_class)
modelmetric.eva_metric(y_label, y_class)
# Out:
# TrueNegatives result:  129259.0
# TruePositives result:  75082.0
# FalseNegatives result:  149.0
# FalsePositives result:  2932.0
# Recall result:  0.99801946
# Precision result:  0.962417

# %%
mf = ModelFigre("../model_record", dir_name, model_)
mf.loss_graph()
mf.recall_graph()
mf.precision_graph()
mf.cross_entropy_graph()
# fig.save_model(net,dir_name)

# %%
mf.lr_graph()

# %%
# model.save('../model_record/'+dir_name+'/model/model.h5')
