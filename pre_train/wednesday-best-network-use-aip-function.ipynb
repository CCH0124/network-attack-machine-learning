# %% [markdown]
# ## 20200923-181126-network-RMSprop

# %%
import tensorflow as tf
import numpy as np
import sys
sys.path.append('../')
import utils.data_preprocess as preprocess
from utils.model_metrics import ModelMetric
from utils.mode_figure import ModelFigre
import datetime
from utils.model_callback import step_decay, exp_decay, MyStopTrainCallBack

# %%
modelmetric = ModelMetric()

# %%
from tensorflow.keras.layers import LSTM, Bidirectional, BatchNormalization, GaussianNoise, Flatten, Dense, Input, Activation
from tensorflow.keras import Model
dos_input = Input(shape=(1, 77))
forward_layer_one = LSTM(64, kernel_constraint=tf.keras.constraints.MaxNorm(max_value=4) , recurrent_constraint=tf.keras.constraints.MaxNorm(max_value=4), return_sequences=True)
backward_layer_one = LSTM(64, kernel_constraint=tf.keras.constraints.MaxNorm(max_value=4) , recurrent_constraint=tf.keras.constraints.MaxNorm(max_value=4), return_sequences=True , go_backwards=True)
bi_one = Bidirectional(forward_layer_one, backward_layer=backward_layer_one, name='bi_one')(dos_input)

noise_one = GaussianNoise(0.5)(bi_one)

bn_one = BatchNormalization()(noise_one)

forward_layer_two = LSTM(32, return_sequences=True)
backward_layer_two = LSTM(32, return_sequences=True, go_backwards=True)
bi_two = Bidirectional(forward_layer_two, backward_layer=backward_layer_two, name='bi_two')(bn_one)

bn_two = BatchNormalization()(bi_two)

forward_layer_three = LSTM(16,)
backward_layer_three = LSTM(16, go_backwards=True)
bi_three = Bidirectional(forward_layer_three, backward_layer=backward_layer_three, name='bi_three')(bn_two)

bn_three = BatchNormalization()(bi_three)

flatten_one = Flatten()(bn_three)

dense_four = Dense(16, kernel_constraint=tf.keras.constraints.MaxNorm(max_value=4), name='dense_three')(flatten_one)
noise_two = GaussianNoise(0.5)(dense_four)
avtivation_four = Activation(tf.nn.relu6, name='dense_four_activation')(noise_two)

bn_four = BatchNormalization()(avtivation_four)

dense = Dense(2, name='classification')(bn_four)
output_res = Activation(tf.nn.softmax, name='classifi')(dense)

model = Model(inputs=dos_input, outputs=output_res)

# algorithm = tf.keras.optimizers.RMSprop(learning_rate=0.001, rho=0.9, clipvalue=0.3, momentum=0.9, epsilon=1e-07, decay= 1e-06, centered=False, name='RMSprop')
algorithm = tf.keras.optimizers.SGD(learning_rate=0.05, momentum=0.99, clipvalue=0.2, nesterov=True, name='SGD')

model.compile(optimizer=algorithm, loss='binary_crossentropy', metrics=modelmetric.metric('binary_crossentropy')) # categorical_crossentropycategorical_crossentropy

# %%
from tensorflow.keras import callbacks
dir_name = datetime.datetime.now().strftime("Best-%Y%m%d-%H%M%S-SGD")

logdir = os.path.join("../tensorboard", dir_name)
tensorboard_callback = callbacks.TensorBoard(logdir, histogram_freq=1)
lrate = callbacks.LearningRateScheduler(step_decay)
csv_log = tf.keras.callbacks.CSVLogger('../model_record/'+dir_name+"/log", separator=',', append=False)
if not os.path.isdir('../model_record/'+dir_name):
    os.mkdir('../model_record/'+dir_name)
    os.mkdir('../model_record/'+dir_name+'/model')
# stop_train = MyStopTrainCallBack()
# callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
pre = preprocess.preprocess("D:/DataSet/CICIDS2017/CSV/Wednesday-workingHours.pcap_ISCX.csv", labelColumnName='Label', depth=2)
X_train, X_test, y_train, y_test = pre.preprocessing()
X_train = tf.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = tf.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
import numpy as np
model_ = model.fit(X_train, y_train, epochs=100, batch_size=512, validation_split=0.3, callbacks=[tensorboard_callback, csv_log, lrate], verbose=1) # lrate
# Out:
# 89 - val_binary_accuracy: 0.9853 - val_binary_crossentropy: 0.0405 - lr: 0.0016
# Epoch 64/100
# 662/662 [==============================] - 16s 25ms/step - loss: 0.0422 - tp: 333518.0000 - fp: 5270.0000 - tn: 333518.0000 - fn: 5270.0000 - acc: 0.0062 - precision: 0.9844 - recall: 0.9844 - auc: 0.9988 - binary_accuracy: 0.9844 - binary_crossentropy: 0.0422 - val_loss: 0.0406 - val_tp: 143031.0000 - val_fp: 2165.0000 - val_tn: 143031.0000 - val_fn: 2165.0000 - val_acc: 0.0048 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0406 - lr: 0.0016
# Epoch 65/100
# 662/662 [==============================] - 18s 27ms/step - loss: 0.0425 - tp: 333484.0000 - fp: 5304.0000 - tn: 333484.0000 - fn: 5304.0000 - acc: 0.0063 - precision: 0.9843 - recall: 0.9843 - auc: 0.9988 - binary_accuracy: 0.9843 - binary_crossentropy: 0.0425 - val_loss: 0.0405 - val_tp: 143065.0000 - val_fp: 2131.0000 - val_tn: 143065.0000 - val_fn: 2131.0000 - val_acc: 0.0045 - val_precision: 0.9853 - val_recall: 0.9853 - val_auc: 0.9989 - val_binary_accuracy: 0.9853 - val_binary_crossentropy: 0.0405 - lr: 0.0016
# Epoch 66/100
# 662/662 [==============================] - 18s 27ms/step - loss: 0.0423 - tp: 333492.0000 - fp: 5296.0000 - tn: 333492.0000 - fn: 5296.0000 - acc: 0.0065 - precision: 0.9844 - recall: 0.9844 - auc: 0.9988 - binary_accuracy: 0.9844 - binary_crossentropy: 0.0423 - val_loss: 0.0407 - val_tp: 143026.0000 - val_fp: 2170.0000 - val_tn: 143026.0000 - val_fn: 2170.0000 - val_acc: 0.0053 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0407 - lr: 0.0016
# Epoch 67/100
# 662/662 [==============================] - 16s 25ms/step - loss: 0.0421 - tp: 333529.0000 - fp: 5259.0000 - tn: 333529.0000 - fn: 5259.0000 - acc: 0.0080 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0421 - val_loss: 0.0406 - val_tp: 143028.0000 - val_fp: 2168.0000 - val_tn: 143028.0000 - val_fn: 2168.0000 - val_acc: 0.0083 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0406 - lr: 0.0016
# Epoch 68/100
# 662/662 [==============================] - 16s 24ms/step - loss: 0.0423 - tp: 333536.0000 - fp: 5252.0000 - tn: 333536.0000 - fn: 5252.0000 - acc: 0.0082 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0423 - val_loss: 0.0407 - val_tp: 143028.0000 - val_fp: 2168.0000 - val_tn: 143028.0000 - val_fn: 2168.0000 - val_acc: 0.0083 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0407 - lr: 0.0016
# Epoch 69/100
# 662/662 [==============================] - 15s 23ms/step - loss: 0.0423 - tp: 333479.0000 - fp: 5309.0000 - tn: 333479.0000 - fn: 5309.0000 - acc: 0.0083 - precision: 0.9843 - recall: 0.9843 - auc: 0.9988 - binary_accuracy: 0.9843 - binary_crossentropy: 0.0423 - val_loss: 0.0407 - val_tp: 143029.0000 - val_fp: 2167.0000 - val_tn: 143029.0000 - val_fn: 2167.0000 - val_acc: 0.0083 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0407 - lr: 0.0016
# Epoch 70/100
# 662/662 [==============================] - 16s 24ms/step - loss: 0.0422 - tp: 333525.0000 - fp: 5263.0000 - tn: 333525.0000 - fn: 5263.0000 - acc: 0.0078 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0422 - val_loss: 0.0406 - val_tp: 143031.0000 - val_fp: 2165.0000 - val_tn: 143031.0000 - val_fn: 2165.0000 - val_acc: 0.0068 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0406 - lr: 7.8125e-04
# Epoch 71/100
# 662/662 [==============================] - 16s 24ms/step - loss: 0.0421 - tp: 333523.0000 - fp: 5265.0000 - tn: 333523.0000 - fn: 5265.0000 - acc: 0.0076 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0421 - val_loss: 0.0406 - val_tp: 143032.0000 - val_fp: 2164.0000 - val_tn: 143032.0000 - val_fn: 2164.0000 - val_acc: 0.0076 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0406 - lr: 7.8125e-04
# Epoch 72/100
# 662/662 [==============================] - 17s 26ms/step - loss: 0.0422 - tp: 333480.0000 - fp: 5308.0000 - tn: 333480.0000 - fn: 5308.0000 - acc: 0.0079 - precision: 0.9843 - recall: 0.9843 - auc: 0.9988 - binary_accuracy: 0.9843 - binary_crossentropy: 0.0422 - val_loss: 0.0406 - val_tp: 143032.0000 - val_fp: 2164.0000 - val_tn: 143032.0000 - val_fn: 2164.0000 - val_acc: 0.0074 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0406 - lr: 7.8125e-04
# Epoch 73/100
# 662/662 [==============================] - 15s 23ms/step - loss: 0.0422 - tp: 333487.0000 - fp: 5301.0000 - tn: 333487.0000 - fn: 5301.0000 - acc: 0.0080 - precision: 0.9844 - recall: 0.9844 - auc: 0.9988 - binary_accuracy: 0.9844 - binary_crossentropy: 0.0422 - val_loss: 0.0406 - val_tp: 143042.0000 - val_fp: 2154.0000 - val_tn: 143042.0000 - val_fn: 2154.0000 - val_acc: 0.0076 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9989 - val_binary_accuracy: 0.9852 - val_binary_crossentropy: 0.0406 - lr: 7.8125e-04
# Epoch 74/100
# 662/662 [==============================] - 15s 22ms/step - loss: 0.0423 - tp: 333492.0000 - fp: 5296.0000 - tn: 333492.0000 - fn: 5296.0000 - acc: 0.0079 - precision: 0.9844 - recall: 0.9844 - auc: 0.9988 - binary_accuracy: 0.9844 - binary_crossentropy: 0.0423 - val_loss: 0.0405 - val_tp: 143062.0000 - val_fp: 2134.0000 - val_tn: 143062.0000 - val_fn: 2134.0000 - val_acc: 0.0084 - val_precision: 0.9853 - val_recall: 0.9853 - val_auc: 0.9989 - val_binary_accuracy: 0.9853 - val_binary_crossentropy: 0.0405 - lr: 7.8125e-04
# Epoch 75/100
# 662/662 [==============================] - 15s 23ms/step - loss: 0.0423 - tp: 333522.0000 - fp: 5266.0000 - tn: 333522.0000 - fn: 5266.0000 - acc: 0.0084 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0423 - val_loss: 0.0406 - val_tp: 143047.0000 - val_fp: 2149.0000 - val_tn: 143047.0000 - val_fn: 2149.0000 - val_acc: 0.0090 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9989 - val_binary_accuracy: 0.9852 - val_binary_crossentropy: 0.0406 - lr: 7.8125e-04
# Epoch 76/100
# 662/662 [==============================] - 17s 25ms/step - loss: 0.0421 - tp: 333560.0000 - fp: 5228.0000 - tn: 333560.0000 - fn: 5228.0000 - acc: 0.0083 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - binary_accuracy: 0.9846 - binary_crossentropy: 0.0421 - val_loss: 0.0407 - val_tp: 143030.0000 - val_fp: 2166.0000 - val_tn: 143030.0000 - val_fn: 2166.0000 - val_acc: 0.0099 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0407 - lr: 7.8125e-04
# Epoch 77/100
# 662/662 [==============================] - 17s 26ms/step - loss: 0.0422 - tp: 333541.0000 - fp: 5247.0000 - tn: 333541.0000 - fn: 5247.0000 - acc: 0.0086 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0422 - val_loss: 0.0405 - val_tp: 143069.0000 - val_fp: 2127.0000 - val_tn: 143069.0000 - val_fn: 2127.0000 - val_acc: 0.0102 - val_precision: 0.9854 - val_recall: 0.9854 - val_auc: 0.9989 - val_binary_accuracy: 0.9854 - val_binary_crossentropy: 0.0405 - lr: 7.8125e-04
# Epoch 78/100
# 662/662 [==============================] - 17s 25ms/step - loss: 0.0421 - tp: 333509.0000 - fp: 5279.0000 - tn: 333509.0000 - fn: 5279.0000 - acc: 0.0093 - precision: 0.9844 - recall: 0.9844 - auc: 0.9988 - binary_accuracy: 0.9844 - binary_crossentropy: 0.0421 - val_loss: 0.0406 - val_tp: 143040.0000 - val_fp: 2156.0000 - val_tn: 143040.0000 - val_fn: 2156.0000 - val_acc: 0.0114 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9989 - val_binary_accuracy: 0.9852 - val_binary_crossentropy: 0.0406 - lr: 7.8125e-04
# Epoch 79/100
# 662/662 [==============================] - 17s 26ms/step - loss: 0.0422 - tp: 333513.0000 - fp: 5275.0000 - tn: 333513.0000 - fn: 5275.0000 - acc: 0.0095 - precision: 0.9844 - recall: 0.9844 - auc: 0.9988 - binary_accuracy: 0.9844 - binary_crossentropy: 0.0422 - val_loss: 0.0407 - val_tp: 143027.0000 - val_fp: 2169.0000 - val_tn: 143027.0000 - val_fn: 2169.0000 - val_acc: 0.0116 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9988 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0407 - lr: 7.8125e-04
# Epoch 80/100
# 662/662 [==============================] - 17s 26ms/step - loss: 0.0421 - tp: 333550.0000 - fp: 5238.0000 - tn: 333550.0000 - fn: 5238.0000 - acc: 0.0095 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0421 - val_loss: 0.0406 - val_tp: 143035.0000 - val_fp: 2161.0000 - val_tn: 143035.0000 - val_fn: 2161.0000 - val_acc: 0.0117 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0406 - lr: 3.9063e-04
# Epoch 81/100
# 662/662 [==============================] - 18s 27ms/step - loss: 0.0420 - tp: 333551.0000 - fp: 5237.0000 - tn: 333551.0000 - fn: 5237.0000 - acc: 0.0097 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0420 - val_loss: 0.0406 - val_tp: 143034.0000 - val_fp: 2162.0000 - val_tn: 143034.0000 - val_fn: 2162.0000 - val_acc: 0.0117 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0406 - lr: 3.9063e-04
# Epoch 82/100
# 662/662 [==============================] - 19s 28ms/step - loss: 0.0421 - tp: 333539.0000 - fp: 5249.0000 - tn: 333539.0000 - fn: 5249.0000 - acc: 0.0092 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0421 - val_loss: 0.0406 - val_tp: 143036.0000 - val_fp: 2160.0000 - val_tn: 143036.0000 - val_fn: 2160.0000 - val_acc: 0.0119 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0406 - lr: 3.9063e-04
# Epoch 83/100
# 662/662 [==============================] - 19s 29ms/step - loss: 0.0422 - tp: 333533.0000 - fp: 5255.0000 - tn: 333533.0000 - fn: 5255.0000 - acc: 0.0096 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0422 - val_loss: 0.0406 - val_tp: 143034.0000 - val_fp: 2162.0000 - val_tn: 143034.0000 - val_fn: 2162.0000 - val_acc: 0.0116 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0406 - lr: 3.9063e-04
# Epoch 84/100
# 662/662 [==============================] - 18s 28ms/step - loss: 0.0419 - tp: 333550.0000 - fp: 5238.0000 - tn: 333550.0000 - fn: 5238.0000 - acc: 0.0095 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0419 - val_loss: 0.0406 - val_tp: 143046.0000 - val_fp: 2150.0000 - val_tn: 143046.0000 - val_fn: 2150.0000 - val_acc: 0.0118 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9989 - val_binary_accuracy: 0.9852 - val_binary_crossentropy: 0.0406 - lr: 3.9063e-04
# Epoch 85/100
# 662/662 [==============================] - 19s 28ms/step - loss: 0.0421 - tp: 333523.0000 - fp: 5265.0000 - tn: 333523.0000 - fn: 5265.0000 - acc: 0.0096 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0421 - val_loss: 0.0406 - val_tp: 143034.0000 - val_fp: 2162.0000 - val_tn: 143034.0000 - val_fn: 2162.0000 - val_acc: 0.0113 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0406 - lr: 3.9063e-04
# Epoch 86/100
# 662/662 [==============================] - 20s 30ms/step - loss: 0.0423 - tp: 333508.0000 - fp: 5280.0000 - tn: 333508.0000 - fn: 5280.0000 - acc: 0.0092 - precision: 0.9844 - recall: 0.9844 - auc: 0.9988 - binary_accuracy: 0.9844 - binary_crossentropy: 0.0423 - val_loss: 0.0406 - val_tp: 143034.0000 - val_fp: 2162.0000 - val_tn: 143034.0000 - val_fn: 2162.0000 - val_acc: 0.0113 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0406 - lr: 3.9063e-04
# Epoch 87/100
# 662/662 [==============================] - 17s 26ms/step - loss: 0.0423 - tp: 333488.0000 - fp: 5300.0000 - tn: 333488.0000 - fn: 5300.0000 - acc: 0.0094 - precision: 0.9844 - recall: 0.9844 - auc: 0.9988 - binary_accuracy: 0.9844 - binary_crossentropy: 0.0423 - val_loss: 0.0406 - val_tp: 143035.0000 - val_fp: 2161.0000 - val_tn: 143035.0000 - val_fn: 2161.0000 - val_acc: 0.0112 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0406 - lr: 3.9063e-04
# Epoch 88/100
# 662/662 [==============================] - 17s 25ms/step - loss: 0.0420 - tp: 333573.0000 - fp: 5215.0000 - tn: 333573.0000 - fn: 5215.0000 - acc: 0.0090 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - binary_accuracy: 0.9846 - binary_crossentropy: 0.0420 - val_loss: 0.0406 - val_tp: 143041.0000 - val_fp: 2155.0000 - val_tn: 143041.0000 - val_fn: 2155.0000 - val_acc: 0.0111 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9989 - val_binary_accuracy: 0.9852 - val_binary_crossentropy: 0.0406 - lr: 3.9063e-04
# Epoch 89/100
# 662/662 [==============================] - 16s 25ms/step - loss: 0.0423 - tp: 333535.0000 - fp: 5253.0000 - tn: 333535.0000 - fn: 5253.0000 - acc: 0.0088 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0423 - val_loss: 0.0406 - val_tp: 143034.0000 - val_fp: 2162.0000 - val_tn: 143034.0000 - val_fn: 2162.0000 - val_acc: 0.0095 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0406 - lr: 3.9063e-04
# Epoch 90/100
# 662/662 [==============================] - 16s 25ms/step - loss: 0.0420 - tp: 333568.0000 - fp: 5220.0000 - tn: 333568.0000 - fn: 5220.0000 - acc: 0.0088 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - binary_accuracy: 0.9846 - binary_crossentropy: 0.0420 - val_loss: 0.0406 - val_tp: 143034.0000 - val_fp: 2162.0000 - val_tn: 143034.0000 - val_fn: 2162.0000 - val_acc: 0.0109 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0406 - lr: 1.9531e-04
# Epoch 91/100
# 662/662 [==============================] - 16s 24ms/step - loss: 0.0420 - tp: 333574.0000 - fp: 5214.0000 - tn: 333574.0000 - fn: 5214.0000 - acc: 0.0089 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - binary_accuracy: 0.9846 - binary_crossentropy: 0.0420 - val_loss: 0.0406 - val_tp: 143034.0000 - val_fp: 2162.0000 - val_tn: 143034.0000 - val_fn: 2162.0000 - val_acc: 0.0110 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0406 - lr: 1.9531e-04
# Epoch 92/100
# 662/662 [==============================] - 16s 25ms/step - loss: 0.0420 - tp: 333557.0000 - fp: 5231.0000 - tn: 333557.0000 - fn: 5231.0000 - acc: 0.0092 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - binary_accuracy: 0.9846 - binary_crossentropy: 0.0420 - val_loss: 0.0406 - val_tp: 143038.0000 - val_fp: 2158.0000 - val_tn: 143038.0000 - val_fn: 2158.0000 - val_acc: 0.0113 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0406 - lr: 1.9531e-04
# Epoch 93/100
# 662/662 [==============================] - 16s 25ms/step - loss: 0.0420 - tp: 333577.0000 - fp: 5211.0000 - tn: 333577.0000 - fn: 5211.0000 - acc: 0.0093 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - binary_accuracy: 0.9846 - binary_crossentropy: 0.0420 - val_loss: 0.0405 - val_tp: 143061.0000 - val_fp: 2135.0000 - val_tn: 143061.0000 - val_fn: 2135.0000 - val_acc: 0.0113 - val_precision: 0.9853 - val_recall: 0.9853 - val_auc: 0.9989 - val_binary_accuracy: 0.9853 - val_binary_crossentropy: 0.0405 - lr: 1.9531e-04
# Epoch 94/100
# 662/662 [==============================] - 17s 25ms/step - loss: 0.0423 - tp: 333564.0000 - fp: 5224.0000 - tn: 333564.0000 - fn: 5224.0000 - acc: 0.0093 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - binary_accuracy: 0.9846 - binary_crossentropy: 0.0423 - val_loss: 0.0406 - val_tp: 143034.0000 - val_fp: 2162.0000 - val_tn: 143034.0000 - val_fn: 2162.0000 - val_acc: 0.0107 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0406 - lr: 1.9531e-04
# Epoch 95/100
# 662/662 [==============================] - 17s 26ms/step - loss: 0.0421 - tp: 333539.0000 - fp: 5249.0000 - tn: 333539.0000 - fn: 5249.0000 - acc: 0.0091 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0421 - val_loss: 0.0405 - val_tp: 143066.0000 - val_fp: 2130.0000 - val_tn: 143066.0000 - val_fn: 2130.0000 - val_acc: 0.0114 - val_precision: 0.9853 - val_recall: 0.9853 - val_auc: 0.9989 - val_binary_accuracy: 0.9853 - val_binary_crossentropy: 0.0405 - lr: 1.9531e-04
# Epoch 96/100
# 662/662 [==============================] - 17s 26ms/step - loss: 0.0421 - tp: 333522.0000 - fp: 5266.0000 - tn: 333522.0000 - fn: 5266.0000 - acc: 0.0091 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0421 - val_loss: 0.0405 - val_tp: 143061.0000 - val_fp: 2135.0000 - val_tn: 143061.0000 - val_fn: 2135.0000 - val_acc: 0.0110 - val_precision: 0.9853 - val_recall: 0.9853 - val_auc: 0.9989 - val_binary_accuracy: 0.9853 - val_binary_crossentropy: 0.0405 - lr: 1.9531e-04
# Epoch 97/100
# 662/662 [==============================] - 17s 26ms/step - loss: 0.0420 - tp: 333532.0000 - fp: 5256.0000 - tn: 333532.0000 - fn: 5256.0000 - acc: 0.0093 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0420 - val_loss: 0.0405 - val_tp: 143059.0000 - val_fp: 2137.0000 - val_tn: 143059.0000 - val_fn: 2137.0000 - val_acc: 0.0109 - val_precision: 0.9853 - val_recall: 0.9853 - val_auc: 0.9989 - val_binary_accuracy: 0.9853 - val_binary_crossentropy: 0.0405 - lr: 1.9531e-04
# Epoch 98/100
# 662/662 [==============================] - 18s 27ms/step - loss: 0.0421 - tp: 333539.0000 - fp: 5249.0000 - tn: 333539.0000 - fn: 5249.0000 - acc: 0.0092 - precision: 0.9845 - recall: 0.9845 - auc: 0.9988 - binary_accuracy: 0.9845 - binary_crossentropy: 0.0421 - val_loss: 0.0406 - val_tp: 143036.0000 - val_fp: 2160.0000 - val_tn: 143036.0000 - val_fn: 2160.0000 - val_acc: 0.0112 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9989 - val_binary_accuracy: 0.9851 - val_binary_crossentropy: 0.0406 - lr: 1.9531e-04
# Epoch 99/100
# 662/662 [==============================] - 17s 26ms/step - loss: 0.0423 - tp: 333513.0000 - fp: 5275.0000 - tn: 333513.0000 - fn: 5275.0000 - acc: 0.0092 - precision: 0.9844 - recall: 0.9844 - auc: 0.9988 - binary_accuracy: 0.9844 - binary_crossentropy: 0.0423 - val_loss: 0.0406 - val_tp: 143042.0000 - val_fp: 2154.0000 - val_tn: 143042.0000 - val_fn: 2154.0000 - val_acc: 0.0111 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9989 - val_binary_accuracy: 0.9852 - val_binary_crossentropy: 0.0406 - lr: 1.9531e-04
# Epoch 100/100
# 662/662 [==============================] - 19s 29ms/step - loss: 0.0420 - tp: 333563.0000 - fp: 5225.0000 - tn: 333563.0000 - fn: 5225.0000 - acc: 0.0090 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - binary_accuracy: 0.9846 - binary_crossentropy: 0.0420 - val_loss: 0.0406 - val_tp: 143042.0000 - val_fp: 2154.0000 - val_tn: 143042.0000 - val_fn: 2154.0000 - val_acc: 0.0110 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9989 - val_binary_accuracy: 0.9852 - val_binary_crossentropy: 0.0406 - lr: 9.7656e-05

# %%
results  = model.evaluate(X_test, y_test, verbose=1)
modelmetric.getTrainMetricValue(model, results)
# Out:
# 6482/6482 [==============================] - 66s 10ms/step - loss: 0.0402 - tp: 204424.0000 - fp: 2998.0000 - tn: 204424.0000 - fn: 2998.0000 - acc: 0.0110 - precision: 0.9855 - recall: 0.9855 - auc: 0.9989 - binary_accuracy: 0.9855 - binary_crossentropy: 0.0402
# loss :  0.04015178233385086
# tp :  204424.0
# fp :  2998.0
# tn :  204424.0
# fn :  2998.0
# acc :  0.011001725681126118
# precision :  0.985546350479126
# recall :  0.985546350479126
# auc :  0.9989038109779358
# binary_accuracy :  0.985546350479126
# binary_crossentropy :  0.04015178233385086

# %%
y_pred = model.predict(X_test)
y_class = np.argmax(y_pred, axis=1)
y_label = np.argmax(y_test, axis=1)
modelmetric.confusion_matrix(y_label, y_class)
modelmetric.eva_metric(y_label, y_class)
# Out:
# TrueNegatives result:  129157.0
# TruePositives result:  75267.0
# FalseNegatives result:  134.0
# FalsePositives result:  2864.0
# Recall result:  0.9982228
# Precision result:  0.9633436

# %%
mf = ModelFigre("../model_record", dir_name, model_)
mf.loss_graph()
mf.recall_graph()
mf.precision_graph()
mf.cross_entropy_graph()
# fig.save_model(net,dir_name)

# %%
mf.lr_graph()

# %%
model.save('../model_record/'+dir_name+'/model/model.h5')
